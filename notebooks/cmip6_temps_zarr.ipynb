# %% [markdown]
# # Access CMIP6 zarr data from AWS using the osdf protocol and compute GMSTA
# - This workflow is inspired by https://gallery.pangeo.io/repos/pangeo-gallery/cmip6/global_mean_surface_temp.html
#
# ## Table of Contents
# - [Section 1: Introduction](#Section-1:-Introduction)
# - [Section 2: Select Dask Cluster](#Section-2:-Select-Dask-Cluster)
# - [Section 3: Data Loading](#Section-3:-Data-Loading)
# - [Section 4: Data Analysis](#Section-4:-Data-Analysis)

# %% [markdown]
# ## Section 1: Introduction
# - Load python packkages
# - Load catalog url

# %%
from matplotlib import pyplot as plt
import xarray as xr
import numpy as np
import dask
from dask.diagnostics import progress
from tqdm.autonotebook import tqdm
import intake
import fsspec
import seaborn as sns
import re
import aiohttp
from dask_jobqueue import PBSCluster
import pandas as pd
# Out:
# /glade/derecho/scratch/harshah/tmp/ipykernel_33606/493514256.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import fsspec.implementations.http as fshttp
from pelicanfs.core import OSDFFileSystem,PelicanMap

# %%
rda_scratch = '/gpfs/csfs1/collections/rda/scratch/harshah'
rda_url     =  'https://data.rda.ucar.edu/'
cat_url     = rda_url +  'd850001/catalogs/osdf/cmip6-aws/cmip6-osdf-zarr.json'

# %% [markdown]
# ## Section 2: Select Dask Cluster

# %% [markdown]
# #### Select the Dask cluster type
# The default will be LocalCluster as that can run on any system.
#
# If running on a HPC computer with a PBS Scheduler, set to True. Otherwise, set to False.

# %%
USE_PBS_SCHEDULER = False

# %% [markdown]
# If running on Jupyter server with Dask Gateway configured, set to True. Otherwise, set to False.

# %%
USE_DASK_GATEWAY = False

# %% [markdown]
# #### Python function for a PBS cluster

# %%
# Create a PBS cluster object
def get_pbs_cluster():
    """ Create cluster through dask_jobqueue.   
    """
    from dask_jobqueue import PBSCluster
    cluster = PBSCluster(
        job_name = 'dask-osdf-24',
        cores = 1,
        memory = '4GiB',
        processes = 1,
        local_directory = rda_scratch + '/dask/spill',
        log_directory = rda_scratch + '/dask/logs/',
        resource_spec = 'select=1:ncpus=1:mem=4GB',
        queue = 'casper',
        walltime = '3:00:00',
        #interface = 'ib0'
        interface = 'ext'
    )
    return cluster

# %% [markdown]
# #### Python function for a Gateway Cluster

# %%
def get_gateway_cluster():
    """ Create cluster through dask_gateway
    """
    from dask_gateway import Gateway

    gateway = Gateway()
    cluster = gateway.new_cluster()
    cluster.adapt(minimum=2, maximum=4)
    return cluster

# %%
def get_local_cluster():
    """ Create cluster using the Jupyter server's resources
    """
    from distributed import LocalCluster, performance_report
    cluster = LocalCluster()    

    cluster.scale(6)
    return cluster

# %% [markdown]
# #### Python logic for a Local Cluster
# This uses True/False boolean logic based on the variables set in the previous cells

# %%
# Obtain dask cluster in one of three ways
if USE_PBS_SCHEDULER:
    cluster = get_pbs_cluster()
elif USE_DASK_GATEWAY:
    cluster = get_gateway_cluster()
else:
    cluster = get_local_cluster()

# Connect to cluster
from distributed import Client
client = Client(cluster)
# Out:
# /glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34613 instead
#   warnings.warn(
# 2025-05-29 17:16:00,428 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:45255' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 11), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 1), ('concatenate-e0f3cbc0a19c5dd6a14472c2fd4373ca', 0, 9), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 4), ('shuffle-split-2b4fd2c94ea92ac06d8504b17c69e50a', 6), ('concatenate-e0f3cbc0a19c5dd6a14472c2fd4373ca', 0, 12), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 3), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 16), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 0), ('concatenate-e0f3cbc0a19c5dd6a14472c2fd4373ca', 0, 11), ('concatenate-e0f3cbc0a19c5dd6a14472c2fd4373ca', 0, 8), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 2), ('concatenate-e0f3cbc0a19c5dd6a14472c2fd4373ca', 0, 10)} (stimulus_id='handle-worker-cleanup-1748560560.427807')
# 2025-05-29 17:16:00,946 - distributed.nanny - WARNING - Restarting worker
# 2025-05-29 17:16:03,390 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:33379' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'shuffle-taker-d4bb5fde07bbd072c1796f04dd80e908', 'original-open_dataset-tas-bb220ddfff903a5403f5e0a94f40dd71', ('shuffle-split-2b4fd2c94ea92ac06d8504b17c69e50a', 5), ('concatenate-e0f3cbc0a19c5dd6a14472c2fd4373ca', 0, 7), ('concatenate-2d6f4e90bc8239dc5749252e5badc971', 0, 0), 'original-open_dataset-tas-33fbc9a1312776d594ffe9951f92443e', ('array-df2eb9c5bc46ec9c5b0d370b12b7c5f7', 0, 0, 0), ('concatenate-f7aa52e2bd4797b379ab34af2d259073', 0, 0)} (stimulus_id='handle-worker-cleanup-1748560563.3906808')
# 2025-05-29 17:16:03,476 - distributed.nanny - WARNING - Restarting worker
# 2025-05-29 17:16:26,340 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:40097' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('shuffle-split-c04b87e992aec7fbd9f7f84d74717ae5', 3), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 0), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 6), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 3), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 9), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 15), ('shuffle-split-75adb7f9d04e5599ee974d7489e53a70', 1), ('mean_agg-aggregate-dd52a8121a9712c997d0a621c5b330dd', 0), ('broadcast_to-rechunk-merge-where-concatenate-8b402d777065f07e44a26489a935bfe3', 0, 0), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 2), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 5), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 11), ('rechunk-split-6d3eb05d596c41270011be7c169d534e', 1), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 8), 'shuffle-taker-d4bb5fde07bbd072c1796f04dd80e908', ('concatenate-342595ff10f8d94b9e5f05d1f4945725', 0, 0), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 1), ('concatenate-821904aeb8695a0bb4f5779dd9ff0d9c', 0, 0), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 4), ('shuffle-split-c04b87e992aec7fbd9f7f84d74717ae5', 4), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 7), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 2, 13)} (stimulus_id='handle-worker-cleanup-1748560586.340469')
# 2025-05-29 17:16:26,460 - distributed.nanny - WARNING - Restarting worker
# 2025-05-29 17:16:28,331 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42885' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {('concatenate-2d6f4e90bc8239dc5749252e5badc971', 0, 3), ('concatenate-f95a8758de9a1e43652d8ef3121b11c1', 0, 0), ('shuffle-split-6372ebd51896ba38574c7a1154a36779', 5), ('shuffle-split-58448caf48a6c5770a2ec4664a6b4ad0', 1), ('mean_agg-aggregate-d2892dd5a7301888d2aa299ced42168d', 2), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 1, 14), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea',
('concatenate-0aeabf7f14d372cd5dbac2bf929720f4', 1, 10), ('concatenate-deb15ee4d3ef7cb860592d743a47a8ea', 0, 9), ('concatenate-821904aeb8695a0bb4f5779dd9ff0d9c', 2, 5), ('concatenate-d4c9bbb235e261c065c158e9805dbf75', 2, 13), ('concatenate-f95a8758de9a1e43652d8ef3121b11c1', 1, 11), ('concatenate-0aeabf7f14d372cd5dbac2bf929720f4', 0, 2), ('concatenate-5ba0a4ef7584394149d079ad25e30cf5', 1, 15), ('concatenate-7c9f6082ac449ac2e5fbdef7a0c7c767', 2, 62), ('concatenate-a559606813ea18e141d862b8cc78f132', 1, 55), ('concatenate-45521e66a683eb16f5698a2ed62434b9', 0, 6), ('concatenate-a559606813ea18e141d862b8cc78f1 ...
# 2025-05-29 17:21:50,745 - distributed.nanny - WARNING - Restarting worker

# %%
# Scale the cluster and display cluster dashboard URL
cluster.scale(8)
cluster
# Out:
# LocalCluster(a84bae3d, 'tcp://127.0.0.1:39307', workers=6, threads=6, memory=24.00 GiB)

# %% [markdown]
# ## Section 3: Data Loading
# - Load catalog and select data subset

# %%
col = intake.open_esm_datastore(cat_url)
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7780 dataset(s) from 522217 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>709</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>522217</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>744</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
[eid for eid in col.df['experiment_id'].unique() if 'ssp' in eid]
# Out:
# ['esm-ssp585-ssp126Lu',
#  'ssp126-ssp370Lu',
#  'ssp370-ssp126Lu',
#  'ssp585',
#  'ssp245',
#  'ssp370-lowNTCF',
#  'ssp370SST-ssp126Lu',
#  'ssp370SST',
#  'ssp370pdSST',
#  'ssp370SST-lowCH4',
#  'ssp370SST-lowNTCF',
#  'ssp126',
#  'ssp119',
#  'ssp370',
#  'esm-ssp585',
#  'ssp245-nat',
#  'ssp245-GHG',
#  'ssp460',
#  'ssp434',
#  'ssp534-over',
#  'ssp245-aer',
#  'ssp245-stratO3',
#  'ssp245-cov-fossil',
#  'ssp245-cov-modgreen',
#  'ssp245-cov-strgreen',
#  'ssp245-covid',
#  'ssp585-bgc']

# %%
# there is currently a significant amount of data for these runs
expts = ['historical', 'ssp245', 'ssp370']

query = dict(
    experiment_id=expts,
    table_id='Amon',
    variable_id=['tas'],
    member_id = 'r1i1p1f1',
    #activity_id = 'CMIP',
)

col_subset = col.search(require_all_on=["source_id"], **query)
col_subset
# Out:
# <p><strong>pangeo-cmip6 catalog with 81 dataset(s) from 81 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
col_subset.df.groupby("source_id")[["experiment_id", "variable_id", "table_id","activity_id"]].nunique()
# Out:
#                   experiment_id  variable_id  table_id  activity_id
# source_id
# ACCESS-CM2                    3            1         1            2
# AWI-CM-1-1-MR                 3            1         1            2
# BCC-CSM2-MR                   3            1         1            2
# CAMS-CSM1-0                   3            1         1            2
# CAS-ESM2-0                    3            1         1            2
# CESM2-WACCM                   3            1         1            2
# CMCC-CM2-SR5                  3            1         1            2
# CMCC-ESM2                     3            1         1            2
# CanESM5                       3            1         1            2
# EC-Earth3                     3            1         1            2
# EC-Earth3-Veg                 3            1         1            2
# EC-Earth3-Veg-LR              3            1         1            2
# FGOALS-f3-L                   3            1         1            2
# FGOALS-g3                     3            1         1            2
# GFDL-ESM4                     3            1         1            2
# IITM-ESM                      3            1         1            2
# INM-CM4-8                     3            1         1            2
# INM-CM5-0                     3            1         1            2
# IPSL-CM6A-LR                  3            1         1            2
# KACE-1-0-G                    3            1         1            2
# MIROC6                        3            1         1            2
# MPI-ESM1-2-HR                 3            1         1            2
# MPI-ESM1-2-LR                 3            1         1            2
# MRI-ESM2-0                    3            1         1            2
# NorESM2-LM                    3            1         1            2
# NorESM2-MM                    3            1         1            2
# TaiESM1                       3            1         1            2

# %%
col_subset.df
# Out:
#     activity_id institution_id      source_id experiment_id member_id  \
# 0          CMIP   CSIRO-ARCCSS     ACCESS-CM2    historical  r1i1p1f1
# 1   ScenarioMIP   CSIRO-ARCCSS     ACCESS-CM2        ssp245  r1i1p1f1
# 2   ScenarioMIP   CSIRO-ARCCSS     ACCESS-CM2        ssp370  r1i1p1f1
# 3   ScenarioMIP            AWI  AWI-CM-1-1-MR        ssp245  r1i1p1f1
# 4   ScenarioMIP            AWI  AWI-CM-1-1-MR        ssp370  r1i1p1f1
# ..          ...            ...            ...           ...       ...
# 76  ScenarioMIP            NCC     NorESM2-MM        ssp370  r1i1p1f1
# 77  ScenarioMIP            NCC     NorESM2-MM        ssp245  r1i1p1f1
# 78         CMIP        AS-RCEC        TaiESM1    historical  r1i1p1f1
# 79  ScenarioMIP        AS-RCEC        TaiESM1        ssp370  r1i1p1f1
# 80  ScenarioMIP        AS-RCEC        TaiESM1        ssp245  r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0      Amon         tas         gn
# 1      Amon         tas         gn
# 2      Amon         tas         gn
# 3      Amon         tas         gn
# 4      Amon         tas         gn
# ..      ...         ...        ...
# 76     Amon         tas         gn
# 77     Amon         tas         gn
# 78     Amon         tas         gn
# 79     Amon         tas         gn
# 80     Amon         tas         gn
#
#                                                zstore  dcpp_init_year  \
# 0   osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 1   osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 2   osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 3   osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 4   osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# ..                                                ...             ...
# 76  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 77  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 78  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 79  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
# 80  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...             NaN
#
#      version
# 0   20191108
# 1   20191108
# 2   20191108
# 3   20190529
# 4   20190529
# ..       ...
# 76  20191108
# 77  20191108
# 78  20200623
# 79  20201014
# 80  20201124
#
# [81 rows x 11 columns]

# %%
# %%time
# dsets_osdf  = col_subset.to_dataset_dict()
# print(f"\nDataset dictionary keys:\n {dsets_osdf.keys()}")

# %%
def drop_all_bounds(ds):
    drop_vars = [vname for vname in ds.coords
                 if (('_bounds') in vname ) or ('_bnds') in vname]
    return ds.drop_vars(drop_vars)

def open_dset(df):
    assert len(df) == 1
    mapper = fsspec.get_mapper(df.zstore.values[0])
    path = df.zstore.values[0][7:]+".zmetadata"
    ds = xr.open_zarr(mapper, consolidated=True)
    a_data = mapper.fs.get_access_data()
    responses = a_data.get_responses(path)
    print(responses)
    return drop_all_bounds(ds)

def open_delayed(df):
    return dask.delayed(open_dset)(df)

from collections import defaultdict
dsets = defaultdict(dict)

for group, df in col_subset.df.groupby(by=['source_id', 'experiment_id']):
    dsets[group[0]][group[1]] = open_delayed(df)

# %%
dsets_ = dask.compute(dict(dsets))[0]

# %%
#calculate global means
def get_lat_name(ds):
    for lat_name in ['lat', 'latitude']:
        if lat_name in ds.coords:
            return lat_name
    raise RuntimeError("Couldn't find a latitude coordinate")

def global_mean(ds):
    lat = ds[get_lat_name(ds)]
    weight = np.cos(np.deg2rad(lat))
    weight /= weight.mean()
    other_dims = set(ds.dims) - {'time'}
    return (ds * weight).mean(other_dims)

# %%
expt_da = xr.DataArray(expts, dims='experiment_id', name='experiment_id',
                       coords={'experiment_id': expts})

dsets_aligned = {}

for k, v in tqdm(dsets_.items()):
    expt_dsets = v.values()
    if any([d is None for d in expt_dsets]):
        print(f"Missing experiment for {k}")
        continue

    for ds in expt_dsets:
        ds.coords['year'] = ds.time.dt.year

    # workaround for
    # https://github.com/pydata/xarray/issues/2237#issuecomment-620961663
    dsets_ann_mean = [v[expt].pipe(global_mean).swap_dims({'time': 'year'})
                             .drop_vars('time').coarsen(year=12).mean()
                      for expt in expts]

    # align everything with the 4xCO2 experiment
    dsets_aligned[k] = xr.concat(dsets_ann_mean, join='outer',dim=expt_da)
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
# %%time
with progress.ProgressBar():
    dsets_aligned_ = dask.compute(dsets_aligned)[0]
# Out:
# CPU times: user 51.9 s, sys: 4.9 s, total: 56.8 s
# Wall time: 7min 48s

# %%
source_ids = list(dsets_aligned_.keys())
source_da = xr.DataArray(source_ids, dims='source_id', name='source_id',
                         coords={'source_id': source_ids})

big_ds = xr.concat([ds.reset_coords(drop=True)
                    for ds in dsets_aligned_.values()],
                    dim=source_da)

big_ds
# Out:
# <xarray.Dataset> Size: 167kB
# Dimensions:        (source_id: 27, experiment_id: 3, year: 251)
# Coordinates:
#   * year           (year) float64 2kB 1.85e+03 1.851e+03 ... 2.099e+03 2.1e+03
#   * experiment_id  (experiment_id) <U10 120B 'historical' 'ssp245' 'ssp370'
#   * source_id      (source_id) <U16 2kB 'ACCESS-CM2' ... 'TaiESM1'
# Data variables:
#     tas            (source_id, experiment_id, year) float64 163kB 287.0 ... 2...

# %% [markdown]
# ### Observational time series data for comparison with ensemble spread
# <!-- obsDataURL = "https://www.esrl.noaa.gov/psd/thredds/dodsC/Datasets/cru/hadcrut4/air.mon.anom.median.nc" -->
# - The observational data we will use is the HadCRUT5 dataset from the UK Met Office
# - The data has been downloaded to NCAR's Research Data Archive (RDA) from https://www.metoffice.gov.uk/hadobs/hadcrut5/
# - We will use an OSDF file system to access this copy from the RDA

# %%
osdf_fs = OSDFFileSystem()
print(osdf_fs)
#
obs_url    = '/ncar/rda/d850001/HadCRUT.5.0.2.0.analysis.summary_series.global.monthly.nc'
#obs_ds = xr.open_dataset(obs_data)
obs_ds = xr.open_dataset(osdf_fs.open(obs_url,mode='rb'),engine='h5netcdf').tas_mean
obs_ds
# Out:
# <pelicanfs.core.OSDFFileSystem object at 0x150fecc6e0b0>
# <xarray.DataArray 'tas_mean' (time: 2101)> Size: 17kB
# [2101 values with dtype=float64]
# Coordinates:
#   * time         (time) datetime64[ns] 17kB 1850-01-16T12:00:00 ... 2025-01-1...
#     latitude     float64 8B ...
#     longitude    float64 8B ...
#     realization  int64 8B ...
# Attributes:
#     long_name:     blended air_temperature_anomaly over land with sea_water_t...
#     units:         K
#     cell_methods:  area: mean (interval: 5.0 degrees_north 5.0 degrees_east) ...

# %%
# obs_url    = 'osdf:///ncar/rda/d850001/HadCRUT.5.0.2.0.analysis.summary_series.global.monthly.zarr'
# print(obs_url)
# #
# obs_ds = xr.open_zarr(obs_url).tas_mean
# # obs_ds

# %%
# Compute annual mean temperatures anomalies
obs_gmsta = obs_ds.resample(time='YS').mean(dim='time')
obs_gmsta
# Out:
# <xarray.DataArray 'tas_mean' (time: 176)> Size: 1kB
# array([-0.41771139, -0.2333498 , -0.22939907, -0.27035444, -0.29152084,
#        -0.29691676, -0.32035371, -0.46723004, -0.38876568, -0.28126517,
#        -0.39016518, -0.42911293, -0.53636936, -0.34424407, -0.46546508,
#        -0.33248133, -0.3412875 , -0.35699412, -0.35182716, -0.31659195,
#        -0.32792752, -0.36856275, -0.32811058, -0.3412969 , -0.37325119,
#        -0.37562594, -0.42410991, -0.10110884, -0.01131519, -0.30363432,
#        -0.31583206, -0.23224553, -0.29553008, -0.34647441, -0.49232007,
#        -0.47112358, -0.42090361, -0.49878576, -0.37937889, -0.24989555,
#        -0.50685816, -0.40131495, -0.50755854, -0.49461923, -0.48376393,
#        -0.44875161, -0.28400727, -0.25980016, -0.48579212, -0.35543365,
#        -0.2344939 , -0.29341025, -0.43895654, -0.5332871 , -0.59751106,
#        -0.40779323, -0.31910879, -0.5040763 , -0.5138197 , -0.53568716,
#        -0.5309095 , -0.53907904, -0.47553864, -0.46701109, -0.26243658,
#        -0.19167219, -0.42002315, -0.54281968, -0.4243641 , -0.32528906,
#        -0.29835507, -0.24044435, -0.3390137 , -0.31768187, -0.3118017 ,
#        -0.28214199, -0.122555  , -0.2291136 , -0.20646581, -0.39244303,
#        -0.17680542, -0.10339768, -0.14546171, -0.32234442, -0.17433685,
#        -0.20605924, -0.16952095, -0.01919895, -0.01220074, -0.0407972 ,
#         0.07593582,  0.0381293 ,  0.00140607,  0.00642158,  0.14410513,
#         0.04308835, -0.11881461, -0.09120561, -0.12466127, -0.14380222,
#        -0.22662181, -0.06115396,  0.01535455,  0.07763075, -0.11675023,
#        -0.19730994, -0.26316562, -0.03533492, -0.01763256, -0.04800481,
#        -0.11545958, -0.01999977, -0.06404272, -0.03681061, -0.30586154,
#        -0.20442047, -0.14889761, -0.1175393 , -0.16864756, -0.03138624,
#        -0.08506409, -0.20588904, -0.09379131,  0.04995016, -0.17252656,
#        -0.11075422, -0.2158369 ,  0.1030885 ,  0.00525597,  0.09085814,
#         0.19607204,  0.25001204,  0.03426828,  0.22380984,  0.04799352,
#         0.04972974,  0.09568698,  0.2430264 ,  0.28215171,  0.17925029,
#         0.36058238,  0.33889653,  0.12489684,  0.16570719,  0.23354978,
#         0.37686615,  0.27668939,  0.42230852,  0.57734169,  0.32448497,
#         0.33108476,  0.48928034,  0.54346649,  0.54417015,  0.46737073,
#         0.60686251,  0.57255269,  0.59170132,  0.46564984,  0.59678164,
#         0.68037139,  0.53769775,  0.57760705,  0.62357535,  0.67287165,
#         0.82511443,  0.93292707,  0.84517425,  0.76265404,  0.89107258,
#         0.92292053,  0.76190556,  0.80130532,  1.10031271,  1.18080012,
#         1.26334445])
# Coordinates:
#     latitude     float64 8B ...
#     longitude    float64 8B ...
#     realization  int64 8B ...
#   * time         (time) datetime64[ns] 1kB 1850-01-01 1851-01-01 ... 2025-01-01
# Attributes:
#     long_name:     blended air_temperature_anomaly over land with sea_water_t...
#     units:         K
#     cell_methods:  area: mean (interval: 5.0 degrees_north 5.0 degrees_east) ...

# %% [markdown]
# ## Section 4: Data Analysis
# - Calculate Global Mean Surface Temperature Anomaly (GMSTA)
# - Grab some observations/ ERA5 reanalysis data
# - Convert xarray datasets to dataframes
# - Use Seaborn to plot GMSTA

# %%
df_all = big_ds.to_dataframe().reset_index()
df_all.head()
# Out:
#     source_id experiment_id    year         tas
# 0  ACCESS-CM2    historical  1850.0  287.007494
# 1  ACCESS-CM2    historical  1851.0  287.016985
# 2  ACCESS-CM2    historical  1852.0  287.174542
# 3  ACCESS-CM2    historical  1853.0  287.070948
# 4  ACCESS-CM2    historical  1854.0  287.141159

# %%
# Compute anomaly w.r.t 1960-1990 baseline
# Define the baseline period
baseline_df = df_all[(df_all["year"] >= 1960) & (df_all["year"] <= 1990)]

# Compute the baseline mean
baseline_mean = baseline_df["tas"].mean()

# Compute anomalies
df_all["tas_anomaly"] = df_all["tas"] - baseline_mean
df_all
# Out:
#         source_id experiment_id    year         tas  tas_anomaly
# 0      ACCESS-CM2    historical  1850.0  287.007494    -0.231967
# 1      ACCESS-CM2    historical  1851.0  287.016985    -0.222476
# 2      ACCESS-CM2    historical  1852.0  287.174542    -0.064918
# 3      ACCESS-CM2    historical  1853.0  287.070948    -0.168513
# 4      ACCESS-CM2    historical  1854.0  287.141159    -0.098302
# ...           ...           ...     ...         ...          ...
# 20326     TaiESM1        ssp370  2096.0  291.798424     4.558963
# 20327     TaiESM1        ssp370  2097.0  291.854096     4.614636
# 20328     TaiESM1        ssp370  2098.0  292.141126     4.901666
# 20329     TaiESM1        ssp370  2099.0  292.206289     4.966828
# 20330     TaiESM1        ssp370  2100.0  292.211119     4.971659
#
# [20331 rows x 5 columns]

# %%
obs_df = obs_gmsta.to_dataframe(name='tas_anomaly').reset_index()
# obs_df

# %%
# Convert 'time' to 'year' (keeping only the year)
obs_df['year'] = obs_df['time'].dt.year

# Drop the original 'time' column since we extracted 'year'
obs_df = obs_df[['year', 'tas_anomaly']]
obs_df
# Out:
#      year  tas_anomaly
# 0    1850    -0.417711
# 1    1851    -0.233350
# 2    1852    -0.229399
# 3    1853    -0.270354
# 4    1854    -0.291521
# ..    ...          ...
# 171  2021     0.761906
# 172  2022     0.801305
# 173  2023     1.100313
# 174  2024     1.180800
# 175  2025     1.263344
#
# [176 rows x 2 columns]

# %%
# Create the main plot
g = sns.relplot(data=df_all, x="year", y="tas_anomaly",
                hue='experiment_id', kind="line", errorbar="sd", aspect=2, palette="Set2")  # Adjust the color palette)

# Get the current axis from the FacetGrid
ax = g.ax

# Overlay the observational data in red
sns.lineplot(data=obs_df, x="year", y="tas_anomaly",color="red", 
             linestyle="dashed", linewidth=2,label="Observations", ax=ax)

# Adjust the legend to include observations
ax.legend(title="Experiment ID + Observations")

# Show the plot
plt.show()

# %%
cluster.close()
# Out:
# 2025-05-29 17:23:31,298 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/comm/tcp.py", line 226, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/worker.py", line 1269, in heartbeat
#     response = await retry_operation(
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/utils_comm.py", line 416, in retry_operation
#     return await retry(
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/utils_comm.py", line 395, in retry
#     return await coro()
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/core.py", line 1259, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/comm/tcp.py", line 137, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:41708 remote=tcp://127.0.0.1:39307>: Stream is closed
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/EC-Earth-Consortium/EC-Earth3/ssp370/r1i1p1f1/Amon/tas/gr/v20200310/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/AS-RCEC/TaiESM1/historical/r1i1p1f1/Amon/tas/gn/v20200623/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/CMCC/CMCC-CM2-SR5/ssp370/r1i1p1f1/Amon/tas/gn/v20200622/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/BCC/BCC-CSM2-MR/ssp370/r1i1p1f1/Amon/tas/gn/v20190314/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/EC-Earth-Consortium/EC-Earth3/historical/r1i1p1f1/Amon/tas/gr/v20200310/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ssp245/r1i1p1f1/Amon/tas/gn/v20191108/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/NCAR/CESM2-WACCM/ssp370/r1i1p1f1/Amon/tas/gn/v20190815/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/EC-Earth-Consortium/EC-Earth3-Veg/ssp370/r1i1p1f1/Amon/tas/gr/v20200225/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/CAMS/CAMS-CSM1-0/ssp370/r1i1p1f1/Amon/tas/gn/v20190708/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/CAS/FGOALS-g3/ssp245/r1i1p1f1/Amon/tas/gn/v20190818/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp370/r1i1p1f1/Amon/tas/gr/v20190119/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/CCCma/CanESM5/ssp245/r1i1p1f1/Amon/tas/gn/v20190429/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/AWI/AWI-CM-1-1-MR/ssp370/r1i1p1f1/Amon/tas/gn/v20190529/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/NCAR/CESM2-WACCM/historical/r1i1p1f1/Amon/tas/gn/v20190227/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/INM/INM-CM5-0/historical/r1i1p1f1/Amon/tas/gr1/v20190610/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/INM/INM-CM5-0/ssp370/r1i1p1f1/Amon/tas/gr1/v20190618/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/CCCR-IITM/IITM-ESM/ssp370/r1i1p1f1/Amon/tas/gn/v20200915/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/INM/INM-CM5-0/ssp245/r1i1p1f1/Amon/tas/gr1/v20190619/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/CAMS/CAMS-CSM1-0/ssp245/r1i1p1f1/Amon/tas/gn/v20190708/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/ScenarioMIP/NIMS-KMA/KACE-1-0-G/ssp245/r1i1p1f1/Amon/tas/gr/v20191217/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/CSIRO-ARCCSS/ACCESS-CM2/historical/r1i1p1f1/Amon/tas/gn/v20191108/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/CMCC/CMCC-ESM2/historical/r1i1p1f1/Amon/tas/gn/v20210114/.zmetadata, Success: True}], True)
# ([{NamespacePath: https://ncar-cache.nationalresearchplatform.org:8443/aws-opendata/us-west-2/cmip6-pds/CMIP6/CMIP/CAS/FGOALS-g3/historical/r1i1p1f1/Amon/tas/gn/v20190818/.zmetadata, Success: True}], True)
# 2025-05-29 17:23:35,270 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2025-05-29 17:23:35,271 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing

# %%
# sns.relplot(data=df_all,x="year", y="tas_anomaly", hue='experiment_id',kind="line", errorbar="sd", aspect=2)
