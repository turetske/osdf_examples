# %% [markdown]
# # Calculate surface ocean heat content using CESM2 LENS data

# %% [markdown]
# - This notebook is adapted from the NCAR gallery in the Pangeo collection
# - https://gallery.pangeo.io/repos/NCAR/notebook-gallery/notebooks/Run-Anywhere/Ocean-Heat-Content/OHC_tutorial.html

# %% [markdown]
# ### Input Data Access
#
# - This notebook illustrates how to compute surface ocean heat content using potential temperature data from CESM2 Large Ensemble Dataset (https://www.cesm.ucar.edu/community-projects/lens2) hosted on NCAR's glade storage.
# - This data is open access and is accessed via OSDF

# %%
# Display output of plots directly in Notebook
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import intake
import numpy as np
import pandas as pd
import xarray as xr
import seaborn as sns
import re
# import nest_asyncio
# nest_asyncio.apply()
# import xesmf as xe
import matplotlib.pyplot as plt

# %%
import fsspec.implementations.http as fshttp
from pelicanfs.core import PelicanFileSystem, PelicanMap, OSDFFileSystem 
import cf_units as cf

# %%
import dask 
from dask_jobqueue import PBSCluster
from dask.distributed import Client
from dask.distributed import performance_report

# %%
init_year0  = '1991'
init_year1  = '2020'
final_year0 = '2071'
final_year1 = '2100'

# %%
def to_daily(ds):
    year = ds.time.dt.year
    day = ds.time.dt.dayofyear

    # assign new coords
    ds = ds.assign_coords(year=("time", year.data), day=("time", day.data))

    # reshape the array to (..., "day", "year")
    return ds.set_index(time=("year", "day")).unstack("time")

# %%
rda_data    = '/glade/campaign/collections/rda/data/harshah'
rda_scratch = '/gpfs/csfs1/collections/rda/scratch/harshah'
# catalog_url = 'https://data.rda.ucar.edu/d010092/catalogs/d010092-posix-zarr.json' #Use this if you are working on NCAR's Casper
catalog_url = 'https://data.rda.ucar.edu/d010092/catalogs/d010092-osdf-zarr.json'

# %% [markdown]
# ## Create a PBS cluster

# %%
# Create a PBS cluster object
cluster = PBSCluster(
    job_name = 'dask-wk24-hpc',
    cores = 1,
    memory = '8GiB',
    processes = 1,
    local_directory = rda_scratch+'/dask/spill',
    log_directory = rda_scratch + '/dask/logs/',
    resource_spec = 'select=1:ncpus=1:mem=8GB',
    queue = 'casper',
    walltime = '5:00:00',
    #interface = 'ib0'
    interface = 'ext'
)

# %%
# Create the client to load the Dashboard
client = Client(cluster)

# %%
n_workers =8
cluster.scale(n_workers)
client.wait_for_workers(n_workers = n_workers)
cluster
# Out:
# PBSCluster(ed2139be, 'tcp://128.117.208.98:37551', workers=8, threads=8, memory=64.00 GiB)

# %% [markdown]
# ## Load CESM LENS2 temperature data

# %%
cesm_cat = intake.open_esm_datastore(catalog_url)
cesm_cat
# Out:
# <p><strong>rda-cesm2-lens-zarr catalog with 40 dataset(s) from 322 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>322</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>forcing_variant</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>313</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# cesm_cat.df['variable'].values

# %%
cesm_temp = cesm_cat.search(variable ='TEMP', frequency ='monthly')
cesm_temp
# Out:
# <p><strong>rda-cesm2-lens-zarr catalog with 3 dataset(s) from 3 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Unnamed: 0</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>long_name</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>component</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>experiment</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>forcing_variant</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>vertical_levels</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>spatial_domain</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>units</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>start_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>end_time</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>path</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cesm_temp.df['path'].values
# Out:
# array(['osdf:///ncar/rda/d010092/ocn/monthly/cesm2LE-historical-cmip6-TEMP.zarr',
#        'osdf:///ncar/rda/d010092/ocn/monthly/cesm2LE-ssp370-cmip6-TEMP.zarr',
#        'osdf:///ncar/rda/d010092/ocn/monthly/cesm2LE-ssp370-smbb-TEMP.zarr'],
#       dtype=object)

# %%
dsets_cesm = cesm_temp.to_dataset_dict()
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'component.experiment.frequency.forcing_variant'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:06&lt;00:00]
#     </div>

# %%
cesm_temp.keys()
# Out:
# ['ocn.historical.monthly.cmip6',
#  'ocn.ssp370.monthly.cmip6',
#  'ocn.ssp370.monthly.smbb']

# %%
historical       = dsets_cesm['ocn.historical.monthly.cmip6']
future_smbb      = dsets_cesm['ocn.ssp370.monthly.smbb']
future_cmip6     = dsets_cesm['ocn.ssp370.monthly.cmip6']

# %%
# %%time
# merge_ds_cmip6 = xr.concat([historical, future_cmip6], dim='time')
# merge_ds_cmip6 = merge_ds_cmip6.dropna(dim='member_id')

# %%
historical
# Out:
# <xarray.Dataset> Size: 3TB
# Dimensions:     (member_id: 50, time: 1980, z_t: 60, nlat: 384, nlon: 320, d2: 2)
# Coordinates:
#   * member_id   (member_id) <U12 2kB 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * time        (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#     time_bound  (time, d2) object 32kB dask.array<chunksize=(1980, 2), meta=np.ndarray>
#   * z_t         (z_t) float32 240B 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
# Dimensions without coordinates: nlat, nlon, d2
# Data variables:
#     TEMP        (member_id, time, z_t, nlat, nlon) float32 3TB dask.array<chunksize=(1, 6, 60, 384, 320), meta=np.ndarray>
# Attributes: (12/25)
#     Conventions:                       CF-1.0; http://www.cgd.ucar.edu/cms/ea...
#     calendar:                          All years have exactly  365 days.
#     cell_methods:                      cell_methods = time: mean ==> the vari...
#     contents:                          Diagnostic and Prognostic Variables
#     model_doi_url:                     https://doi.org/10.5065/D67H1H0V
#     revision:                          $Id$
#     ...                                ...
#     intake_esm_attrs:units:            degC
#     intake_esm_attrs:start_time:       1850-01-16 12:00:00
#     intake_esm_attrs:end_time:         2014-12-16 12:00:00
#     intake_esm_attrs:path:             osdf:///ncar/rda/d010092/ocn/monthly/c...
#     intake_esm_attrs:_data_format_:    zarr
#     intake_esm_dataset_key:            ocn.historical.monthly.cmip6

# %% [markdown]
# #### Change units

# %%
orig_units = cf.Unit(historical.z_t.attrs['units'])
orig_units
# Out:
# Unit('centimeters')

# %%
def change_units(ds, variable_str, variable_bounds_str, target_unit_str):
    orig_units = cf.Unit(ds[variable_str].attrs['units'])
    target_units = cf.Unit(target_unit_str)
    variable_in_new_units = xr.apply_ufunc(orig_units.convert, ds[variable_bounds_str], target_units, dask='parallelized', output_dtypes=[ds[variable_bounds_str].dtype])
    return variable_in_new_units

# %%
historical['z_t']
# Out:
# <xarray.DataArray 'z_t' (z_t: 60)> Size: 240B
# array([5.000000e+02, 1.500000e+03, 2.500000e+03, 3.500000e+03, 4.500000e+03,
#        5.500000e+03, 6.500000e+03, 7.500000e+03, 8.500000e+03, 9.500000e+03,
#        1.050000e+04, 1.150000e+04, 1.250000e+04, 1.350000e+04, 1.450000e+04,
#        1.550000e+04, 1.650984e+04, 1.754790e+04, 1.862913e+04, 1.976603e+04,
#        2.097114e+04, 2.225783e+04, 2.364088e+04, 2.513702e+04, 2.676542e+04,
#        2.854837e+04, 3.051192e+04, 3.268680e+04, 3.510935e+04, 3.782276e+04,
#        4.087846e+04, 4.433777e+04, 4.827367e+04, 5.277280e+04, 5.793729e+04,
#        6.388626e+04, 7.075633e+04, 7.870025e+04, 8.788252e+04, 9.847059e+04,
#        1.106204e+05, 1.244567e+05, 1.400497e+05, 1.573946e+05, 1.764003e+05,
#        1.968944e+05, 2.186457e+05, 2.413972e+05, 2.649001e+05, 2.889385e+05,
#        3.133405e+05, 3.379793e+05, 3.627670e+05, 3.876452e+05, 4.125768e+05,
#        4.375392e+05, 4.625190e+05, 4.875083e+05, 5.125028e+05, 5.375000e+05],
#       dtype=float32)
# Coordinates:
#   * z_t      (z_t) float32 240B 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
# Attributes:
#     long_name:  depth from surface to midpoint of layer
#     positive:   down
#     units:      centimeters
#     valid_max:  537500.0
#     valid_min:  500.0

# %%
depth_levels_in_m = change_units(historical, 'z_t', 'z_t', 'm')
hist_temp_in_degK = change_units(historical, 'TEMP', 'TEMP', 'degK')
fut_cmip6_temp_in_degK = change_units(future_cmip6, 'TEMP', 'TEMP', 'degK')
fut_smbb_temp_in_degK = change_units(future_smbb, 'TEMP', 'TEMP', 'degK')
#
hist_temp_in_degK  = hist_temp_in_degK.assign_coords(z_t=("z_t", depth_levels_in_m['z_t'].data))
hist_temp_in_degK["z_t"].attrs["units"] = "m"
hist_temp_in_degK
# Out:
# <xarray.DataArray (member_id: 50, time: 1980, z_t: 60, nlat: 384, nlon: 320)> Size: 3TB
# dask.array<transpose, shape=(50, 1980, 60, 384, 320), dtype=float32, chunksize=(1, 6, 60, 384, 320), chunktype=numpy.ndarray>
# Coordinates:
#   * member_id  (member_id) <U12 2kB 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * time       (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#   * z_t        (z_t) float32 240B 500.0 1.5e+03 2.5e+03 ... 5.125e+05 5.375e+05
# Dimensions without coordinates: nlat, nlon

# %%
depth_levels_in_m.isel(z_t=slice(0, -1))
# Out:
# <xarray.DataArray (z_t: 59)> Size: 236B
# array([5.0000000e+00, 1.5000000e+01, 2.5000000e+01, 3.5000000e+01,
#        4.5000000e+01, 5.5000000e+01, 6.5000000e+01, 7.5000000e+01,
#        8.5000000e+01, 9.5000000e+01, 1.0500000e+02, 1.1500000e+02,
#        1.2500000e+02, 1.3500000e+02, 1.4500000e+02, 1.5500000e+02,
#        1.6509840e+02, 1.7547905e+02, 1.8629128e+02, 1.9766028e+02,
#        2.0971138e+02, 2.2257828e+02, 2.3640883e+02, 2.5137016e+02,
#        2.6765421e+02, 2.8548364e+02, 3.0511923e+02, 3.2686798e+02,
#        3.5109348e+02, 3.7822763e+02, 4.0878464e+02, 4.4337769e+02,
#        4.8273672e+02, 5.2772803e+02, 5.7937286e+02, 6.3886261e+02,
#        7.0756329e+02, 7.8700250e+02, 8.7882526e+02, 9.8470587e+02,
#        1.1062042e+03, 1.2445669e+03, 1.4004972e+03, 1.5739464e+03,
#        1.7640033e+03, 1.9689442e+03, 2.1864565e+03, 2.4139717e+03,
#        2.6490012e+03, 2.8893848e+03, 3.1334048e+03, 3.3797935e+03,
#        3.6276704e+03, 3.8764519e+03, 4.1257681e+03, 4.3753926e+03,
#        4.6251904e+03, 4.8750835e+03, 5.1250283e+03], dtype=float32)
# Coordinates:
#   * z_t      (z_t) float32 236B 500.0 1.5e+03 2.5e+03 ... 4.875e+05 5.125e+05

# %%
#Compute depth level deltas using z_t levels
depth_level_deltas = depth_levels_in_m.isel(z_t=slice(1, None)).values - depth_levels_in_m.isel(z_t=slice(0, -1)).values
# Optionally, if you want to keep it as an xarray DataArray, re-wrap the result
depth_level_deltas = xr.DataArray(depth_level_deltas, dims=["z_t"], coords={"z_t": depth_levels_in_m.z_t.isel(z_t=slice(0, -1))})
depth_level_deltas
# Out:
# <xarray.DataArray (z_t: 59)> Size: 236B
# array([ 10.      ,  10.      ,  10.      ,  10.      ,  10.      ,
#         10.      ,  10.      ,  10.      ,  10.      ,  10.      ,
#         10.      ,  10.      ,  10.      ,  10.      ,  10.      ,
#         10.098404,  10.380646,  10.812225,  11.369003,  12.051102,
#         12.866898,  13.830551,  14.961334,  16.284042,  17.829437,
#         19.63559 ,  21.748749,  24.225494,  27.134155,  30.557007,
#         34.59305 ,  39.35904 ,  44.991302,  51.644836,  59.489746,
#         68.70068 ,  79.43921 ,  91.822754, 105.880615, 121.49835 ,
#        138.36267 , 155.9303  , 173.44922 , 190.05688 , 204.94092 ,
#        217.51233 , 227.51514 , 235.02954 , 240.38354 , 244.02002 ,
#        246.38867 , 247.87695 , 248.7815  , 249.31616 , 249.62451 ,
#        249.79785 , 249.89307 , 249.94482 , 249.97168 ], dtype=float32)
# Coordinates:
#   * z_t      (z_t) float32 236B 500.0 1.5e+03 2.5e+03 ... 4.875e+05 5.125e+05

# %% [markdown]
# # Compute Ocean Heat content for ocean surface
# - Ocean surface is considered to be the top 100m
# - The formula for this is: $$ H = \rho C \int_0^z T(z) dz $$
#
#
# Where H is ocean heat content, the value we are trying to calculate,
#
# $\rho$ is the density of sea water, $1026 kg/m^3$  ,
#
# $C$ is the specific heat of sea water, $3990 J/(kg K)$  ,
#
# $z$ is the depth limit of the calculation in meters,
#
# and $T(z)$ is the temperature at each depth in degrees Kelvin.

# %%
def calc_ocean_heat(delta_level, temperature):
    rho = 1026 #kg/m^3
    c_p = 3990 #J/(kg K)
    weighted_temperature = delta_level * temperature
    heat = weighted_temperature.sum(dim="z_t")*rho*c_p
    return heat

# %%
# Remember that the coordinate z_t still has values in cm
hist_temp_ocean_surface = hist_temp_in_degK.where(hist_temp_in_degK['z_t'] < 1e4,drop=True)
hist_temp_ocean_surface
# Out:
# <xarray.DataArray (member_id: 50, time: 1980, z_t: 10, nlat: 384, nlon: 320)> Size: 487GB
# dask.array<where, shape=(50, 1980, 10, 384, 320), dtype=float32, chunksize=(1, 6, 10, 384, 320), chunktype=numpy.ndarray>
# Coordinates:
#   * member_id  (member_id) <U12 2kB 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * time       (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
#   * z_t        (z_t) float32 40B 500.0 1.5e+03 2.5e+03 ... 8.5e+03 9.5e+03
# Dimensions without coordinates: nlat, nlon

# %%
depth_level_deltas_surface = depth_level_deltas.where(depth_level_deltas['z_t'] <1e4, drop= True)
depth_level_deltas_surface
# Out:
# <xarray.DataArray (z_t: 10)> Size: 40B
# array([10., 10., 10., 10., 10., 10., 10., 10., 10., 10.], dtype=float32)
# Coordinates:
#   * z_t      (z_t) float32 40B 500.0 1.5e+03 2.5e+03 ... 7.5e+03 8.5e+03 9.5e+03

# %%
hist_ocean_heat = calc_ocean_heat(depth_level_deltas_surface,hist_temp_ocean_surface)
hist_ocean_heat
# Out:
# <xarray.DataArray (member_id: 50, time: 1980, nlat: 384, nlon: 320)> Size: 49GB
# dask.array<mul, shape=(50, 1980, 384, 320), dtype=float32, chunksize=(1, 6, 384, 320), chunktype=numpy.ndarray>
# Coordinates:
#   * member_id  (member_id) <U12 2kB 'r10i1181p1f1' ... 'r9i1301p1f1'
#   * time       (time) object 16kB 1850-01-16 12:00:00 ... 2014-12-16 12:00:00
# Dimensions without coordinates: nlat, nlon

# %% [markdown]
# ### Plot Ocean Heat

# %%
# %%time
# Jan, 1850 average over all memebers
# hist_ocean_avgheat = hist_ocean_heat.mean('member_id')
hist_ocean_avgheat = hist_ocean_heat.isel({'time':[0,-12]}).mean('member_id')
hist_ocean_avgheat
# Out:
# CPU times: user 14.2 ms, sys: 0 ns, total: 14.2 ms
# Wall time: 14.5 ms
# <xarray.DataArray (time: 2, nlat: 384, nlon: 320)> Size: 983kB
# dask.array<mean_agg-aggregate, shape=(2, 384, 320), dtype=float32, chunksize=(2, 384, 320), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 16B 1850-01-16 12:00:00 2014-01-16 12:00:00
# Dimensions without coordinates: nlat, nlon

# %%
# %%time
hist_ocean_avgheat.isel(time=0).plot()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:271, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     220 def plot(
#     221     darray: DataArray,
#     222     *,
#    (...)
#     229     **kwargs: Any,
#     230 ) -> Any:
#     231     """
#     232     Default plot of DataArray using :py:mod:`matplotlib:matplotlib.pyplot`.
#     233
#    (...)
#     267     xarray.DataArray.squeeze
#     268     """
#     269     darray = darray.squeeze(
#     270         d for d, s in darray.sizes.items() if s == 1 and d not in (row, col, hue)
# --> 271     ).compute()
#     273     plot_dims = set(darray.dims)
#     274     plot_dims.discard(row)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataarray.py:1207, in DataArray.compute(self, **kwargs)
#    1182 """Manually trigger loading of this array's data from disk or a
#    1183 remote source into memory and return a new array.
#    1184
#    (...)
#    1204 dask.compute
#    1205 """
#    1206 new = self.copy(deep=False)
# -> 1207 return new.load(**kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataarray.py:1175, in DataArray.load(self, **kwargs)
#    1155 def load(self, **kwargs) -> Self:
#    1156     """Manually trigger loading of this array's data from disk or a
#    1157     remote source into memory and return this array.
#    1158
#    (...)
#    1173     dask.compute
#    1174     """
# -> 1175     ds = self._to_temp_dataset().load(**kwargs)
#    1176     new = self._from_temp_dataset(ds)
#    1177     self._variable = new._variable
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataset.py:899, in Dataset.load(self, **kwargs)
#     896 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     898 # evaluate all the chunked arrays simultaneously
# --> 899 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     900     *lazy_data.values(), **kwargs
#     901 )
#     903 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     904     self.variables[k].data = data
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:580, in __array__()
#     578     return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     579 else:
# --> 580     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:583, in get_duck_array()
#     582 def get_duck_array(self):
# --> 583     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:794, in get_duck_array()
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:664, in get_duck_array()
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
# --> 664     array = array.get_duck_array()
#     665 return _wrap_numpy_scalars(array)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/coding/variables.py:81, in get_duck_array()
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:657, in get_duck_array()
#     653     array = apply_indexer(self.array, self.key)
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:226, in __getitem__()
#     224 elif isinstance(key, indexing.OuterIndexer):
#     225     method = self._oindex
# --> 226 return indexing.explicit_indexing_adapter(
#     227     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     228 )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter()
#     996 """Support explicit indexing by delegating to a raw indexing method.
#     997
#     998 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1015 Indexing result, in the form of a duck numpy-array.
#    1016 """
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#    1021     indexable = NumpyIndexingAdapter(result)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:216, in _getitem()
#     215 def _getitem(self, key):
# --> 216     return self._array[key]
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:795, in __getitem__()
#     793     result = self.vindex[selection]
#     794 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 795     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     796 else:
#     797     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1077, in get_orthogonal_selection()
#    1074 # setup indexer
#    1075 indexer = OrthogonalIndexer(selection, self)
# -> 1077 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1340, in _get_selection()
#    1337 if math.prod(out_shape) > 0:
#    1338     # allow storage to get multiple items at once
#    1339     lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1340     self._chunk_getitems(
#    1341         lchunk_coords,
#    1342         lchunk_selection,
#    1343         out,
#    1344         lout_selection,
#    1345         drop_axes=indexer.drop_axes,
#    1346         fields=fields,
#    1347     )
#    1348 if out.shape:
#    1349     return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:2181, in _chunk_getitems()
#    2179     if not isinstance(self._meta_array, np.ndarray):
#    2180         contexts = ConstantMap(ckeys, constant=Context(meta_array=self._meta_array))
# -> 2181     cdatas = self.chunk_store.getitems(ckeys, contexts=contexts)
#    2183 for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    2184     if ckey in cdatas:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1435, in getitems()
#    1432     continue
#    1433 elif isinstance(v, Exception):
#    1434     # Raise any other exception
# -> 1435     raise v
#    1436 else:
#    1437     # The function calling this method may not recognize the transformed
#    1438     # keys, so we send the values returned by self.map.getitems back into
#    1439     # the original key space.
#    1440     results[keys_transformed[k]] = v
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:245, in _run_coro()
#     243 async def _run_coro(coro, i):
#     244     try:
# --> 245         return await asyncio.wait_for(coro, timeout=timeout), i
#     246     except Exception as e:
#     247         if not return_exceptions:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/asyncio/tasks.py:408, in wait_for()
#     405 loop = events.get_running_loop()
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#     411     fut = ensure_future(fut, loop=loop)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/implementations/http.py:235, in _cat_file()
#     233 session = await self.set_session()
#     234 async with session.get(self.encode_url(url), **kw) as r:
# --> 235     out = await r.read()
#     236     self._raise_not_found_for_status(r, url)
#     237 return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1111, in read()
#    1109 if self._body is None:
#    1110     try:
# -> 1111         self._body = await self.content.read()
#    1112         for trace in self._traces:
#    1113             await trace.send_response_chunk_received(
#    1114                 self.method, self.url, self._body
#    1115             )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:383, in read()
#     381 blocks = []
#     382 while True:
# --> 383     block = await self.readany()
#     384     if not block:
#     385         break
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:405, in readany()
#     401 # TODO: should be `if` instead of `while`
#     402 # because waiter maybe triggered on chunk end,
#     403 # without feeding any data
#     404 while not self._buffer and not self._eof:
# --> 405     await self._wait("readany")
#     407 return self._read_nowait(-1)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:311, in _wait()
#     309 waiter = self._waiter = self._loop.create_future()
#     310 try:
# --> 311     with self._timer:
#     312         await waiter
#     313 finally:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/helpers.py:735, in __exit__()
#     732     self._tasks.pop()
#     734 if exc_type is asyncio.CancelledError and self._cancelled:
# --> 735     raise asyncio.TimeoutError from None
#     736 return None
#
# TimeoutError:

# %%
# %%time
#Plot ocean heat for Jan 2014
hist_ocean_avgheat.isel(time=1).plot()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File <timed eval>:2
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:271, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     220 def plot(
#     221     darray: DataArray,
#     222     *,
#    (...)
#     229     **kwargs: Any,
#     230 ) -> Any:
#     231     """
#     232     Default plot of DataArray using :py:mod:`matplotlib:matplotlib.pyplot`.
#     233
#    (...)
#     267     xarray.DataArray.squeeze
#     268     """
#     269     darray = darray.squeeze(
#     270         d for d, s in darray.sizes.items() if s == 1 and d not in (row, col, hue)
# --> 271     ).compute()
#     273     plot_dims = set(darray.dims)
#     274     plot_dims.discard(row)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataarray.py:1207, in DataArray.compute(self, **kwargs)
#    1182 """Manually trigger loading of this array's data from disk or a
#    1183 remote source into memory and return a new array.
#    1184
#    (...)
#    1204 dask.compute
#    1205 """
#    1206 new = self.copy(deep=False)
# -> 1207 return new.load(**kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataarray.py:1175, in DataArray.load(self, **kwargs)
#    1155 def load(self, **kwargs) -> Self:
#    1156     """Manually trigger loading of this array's data from disk or a
#    1157     remote source into memory and return this array.
#    1158
#    (...)
#    1173     dask.compute
#    1174     """
# -> 1175     ds = self._to_temp_dataset().load(**kwargs)
#    1176     new = self._from_temp_dataset(ds)
#    1177     self._variable = new._variable
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataset.py:899, in Dataset.load(self, **kwargs)
#     896 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     898 # evaluate all the chunked arrays simultaneously
# --> 899 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     900     *lazy_data.values(), **kwargs
#     901 )
#     903 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     904     self.variables[k].data = data
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:580, in __array__()
#     578     return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     579 else:
# --> 580     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:583, in get_duck_array()
#     582 def get_duck_array(self):
# --> 583     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:794, in get_duck_array()
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:664, in get_duck_array()
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
# --> 664     array = array.get_duck_array()
#     665 return _wrap_numpy_scalars(array)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/coding/variables.py:81, in get_duck_array()
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:657, in get_duck_array()
#     653     array = apply_indexer(self.array, self.key)
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:226, in __getitem__()
#     224 elif isinstance(key, indexing.OuterIndexer):
#     225     method = self._oindex
# --> 226 return indexing.explicit_indexing_adapter(
#     227     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     228 )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter()
#     996 """Support explicit indexing by delegating to a raw indexing method.
#     997
#     998 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1015 Indexing result, in the form of a duck numpy-array.
#    1016 """
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#    1021     indexable = NumpyIndexingAdapter(result)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:216, in _getitem()
#     215 def _getitem(self, key):
# --> 216     return self._array[key]
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:795, in __getitem__()
#     793     result = self.vindex[selection]
#     794 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 795     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     796 else:
#     797     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1077, in get_orthogonal_selection()
#    1074 # setup indexer
#    1075 indexer = OrthogonalIndexer(selection, self)
# -> 1077 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1340, in _get_selection()
#    1337 if math.prod(out_shape) > 0:
#    1338     # allow storage to get multiple items at once
#    1339     lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1340     self._chunk_getitems(
#    1341         lchunk_coords,
#    1342         lchunk_selection,
#    1343         out,
#    1344         lout_selection,
#    1345         drop_axes=indexer.drop_axes,
#    1346         fields=fields,
#    1347     )
#    1348 if out.shape:
#    1349     return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:2181, in _chunk_getitems()
#    2179     if not isinstance(self._meta_array, np.ndarray):
#    2180         contexts = ConstantMap(ckeys, constant=Context(meta_array=self._meta_array))
# -> 2181     cdatas = self.chunk_store.getitems(ckeys, contexts=contexts)
#    2183 for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    2184     if ckey in cdatas:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1435, in getitems()
#    1432     continue
#    1433 elif isinstance(v, Exception):
#    1434     # Raise any other exception
# -> 1435     raise v
#    1436 else:
#    1437     # The function calling this method may not recognize the transformed
#    1438     # keys, so we send the values returned by self.map.getitems back into
#    1439     # the original key space.
#    1440     results[keys_transformed[k]] = v
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:245, in _run_coro()
#     243 async def _run_coro(coro, i):
#     244     try:
# --> 245         return await asyncio.wait_for(coro, timeout=timeout), i
#     246     except Exception as e:
#     247         if not return_exceptions:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/asyncio/tasks.py:408, in wait_for()
#     405 loop = events.get_running_loop()
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#     411     fut = ensure_future(fut, loop=loop)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/implementations/http.py:235, in _cat_file()
#     233 session = await self.set_session()
#     234 async with session.get(self.encode_url(url), **kw) as r:
# --> 235     out = await r.read()
#     236     self._raise_not_found_for_status(r, url)
#     237 return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1111, in read()
#    1109 if self._body is None:
#    1110     try:
# -> 1111         self._body = await self.content.read()
#    1112         for trace in self._traces:
#    1113             await trace.send_response_chunk_received(
#    1114                 self.method, self.url, self._body
#    1115             )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:383, in read()
#     381 blocks = []
#     382 while True:
# --> 383     block = await self.readany()
#     384     if not block:
#     385         break
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:405, in readany()
#     401 # TODO: should be `if` instead of `while`
#     402 # because waiter maybe triggered on chunk end,
#     403 # without feeding any data
#     404 while not self._buffer and not self._eof:
# --> 405     await self._wait("readany")
#     407 return self._read_nowait(-1)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:311, in _wait()
#     309 waiter = self._waiter = self._loop.create_future()
#     310 try:
# --> 311     with self._timer:
#     312         await waiter
#     313 finally:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/helpers.py:735, in __exit__()
#     732     self._tasks.pop()
#     734 if exc_type is asyncio.CancelledError and self._cancelled:
# --> 735     raise asyncio.TimeoutError from None
#     736 return None
#
# TimeoutError:

# %% [markdown]
# ### Has the surface ocean heat content increased with time for January ? (Due to Global Warming!)

# %%
hist_ocean_avgheat_ano = hist_ocean_avgheat.isel(time=1) - hist_ocean_avgheat.isel(time=0)

# %%
# %%time
hist_ocean_avgheat_ano.plot()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:271, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     220 def plot(
#     221     darray: DataArray,
#     222     *,
#    (...)
#     229     **kwargs: Any,
#     230 ) -> Any:
#     231     """
#     232     Default plot of DataArray using :py:mod:`matplotlib:matplotlib.pyplot`.
#     233
#    (...)
#     267     xarray.DataArray.squeeze
#     268     """
#     269     darray = darray.squeeze(
#     270         d for d, s in darray.sizes.items() if s == 1 and d not in (row, col, hue)
# --> 271     ).compute()
#     273     plot_dims = set(darray.dims)
#     274     plot_dims.discard(row)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataarray.py:1207, in DataArray.compute(self, **kwargs)
#    1182 """Manually trigger loading of this array's data from disk or a
#    1183 remote source into memory and return a new array.
#    1184
#    (...)
#    1204 dask.compute
#    1205 """
#    1206 new = self.copy(deep=False)
# -> 1207 return new.load(**kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataarray.py:1175, in DataArray.load(self, **kwargs)
#    1155 def load(self, **kwargs) -> Self:
#    1156     """Manually trigger loading of this array's data from disk or a
#    1157     remote source into memory and return this array.
#    1158
#    (...)
#    1173     dask.compute
#    1174     """
# -> 1175     ds = self._to_temp_dataset().load(**kwargs)
#    1176     new = self._from_temp_dataset(ds)
#    1177     self._variable = new._variable
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataset.py:899, in Dataset.load(self, **kwargs)
#     896 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     898 # evaluate all the chunked arrays simultaneously
# --> 899 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     900     *lazy_data.values(), **kwargs
#     901 )
#     903 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     904     self.variables[k].data = data
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:580, in __array__()
#     578     return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     579 else:
# --> 580     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:583, in get_duck_array()
#     582 def get_duck_array(self):
# --> 583     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:794, in get_duck_array()
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:664, in get_duck_array()
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
# --> 664     array = array.get_duck_array()
#     665 return _wrap_numpy_scalars(array)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/coding/variables.py:81, in get_duck_array()
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:657, in get_duck_array()
#     653     array = apply_indexer(self.array, self.key)
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:226, in __getitem__()
#     224 elif isinstance(key, indexing.OuterIndexer):
#     225     method = self._oindex
# --> 226 return indexing.explicit_indexing_adapter(
#     227     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     228 )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter()
#     996 """Support explicit indexing by delegating to a raw indexing method.
#     997
#     998 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1015 Indexing result, in the form of a duck numpy-array.
#    1016 """
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#    1021     indexable = NumpyIndexingAdapter(result)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:216, in _getitem()
#     215 def _getitem(self, key):
# --> 216     return self._array[key]
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:795, in __getitem__()
#     793     result = self.vindex[selection]
#     794 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 795     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     796 else:
#     797     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1077, in get_orthogonal_selection()
#    1074 # setup indexer
#    1075 indexer = OrthogonalIndexer(selection, self)
# -> 1077 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1340, in _get_selection()
#    1337 if math.prod(out_shape) > 0:
#    1338     # allow storage to get multiple items at once
#    1339     lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1340     self._chunk_getitems(
#    1341         lchunk_coords,
#    1342         lchunk_selection,
#    1343         out,
#    1344         lout_selection,
#    1345         drop_axes=indexer.drop_axes,
#    1346         fields=fields,
#    1347     )
#    1348 if out.shape:
#    1349     return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:2181, in _chunk_getitems()
#    2179     if not isinstance(self._meta_array, np.ndarray):
#    2180         contexts = ConstantMap(ckeys, constant=Context(meta_array=self._meta_array))
# -> 2181     cdatas = self.chunk_store.getitems(ckeys, contexts=contexts)
#    2183 for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    2184     if ckey in cdatas:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1435, in getitems()
#    1432     continue
#    1433 elif isinstance(v, Exception):
#    1434     # Raise any other exception
# -> 1435     raise v
#    1436 else:
#    1437     # The function calling this method may not recognize the transformed
#    1438     # keys, so we send the values returned by self.map.getitems back into
#    1439     # the original key space.
#    1440     results[keys_transformed[k]] = v
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:245, in _run_coro()
#     243 async def _run_coro(coro, i):
#     244     try:
# --> 245         return await asyncio.wait_for(coro, timeout=timeout), i
#     246     except Exception as e:
#     247         if not return_exceptions:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/asyncio/tasks.py:408, in wait_for()
#     405 loop = events.get_running_loop()
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#     411     fut = ensure_future(fut, loop=loop)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/implementations/http.py:235, in _cat_file()
#     233 session = await self.set_session()
#     234 async with session.get(self.encode_url(url), **kw) as r:
# --> 235     out = await r.read()
#     236     self._raise_not_found_for_status(r, url)
#     237 return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1111, in read()
#    1109 if self._body is None:
#    1110     try:
# -> 1111         self._body = await self.content.read()
#    1112         for trace in self._traces:
#    1113             await trace.send_response_chunk_received(
#    1114                 self.method, self.url, self._body
#    1115             )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:383, in read()
#     381 blocks = []
#     382 while True:
# --> 383     block = await self.readany()
#     384     if not block:
#     385         break
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:405, in readany()
#     401 # TODO: should be `if` instead of `while`
#     402 # because waiter maybe triggered on chunk end,
#     403 # without feeding any data
#     404 while not self._buffer and not self._eof:
# --> 405     await self._wait("readany")
#     407 return self._read_nowait(-1)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:311, in _wait()
#     309 waiter = self._waiter = self._loop.create_future()
#     310 try:
# --> 311     with self._timer:
#     312         await waiter
#     313 finally:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/helpers.py:735, in __exit__()
#     732     self._tasks.pop()
#     734 if exc_type is asyncio.CancelledError and self._cancelled:
# --> 735     raise asyncio.TimeoutError from None
#     736 return None
#
# TimeoutError:

# %%
cluster.close()
