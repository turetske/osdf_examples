# %% [markdown]
# # Apply MDM and QDM to CMIP6 daily temperatures
# - Daily temperature data is loaded using the OSDF protocol and discovered using an intake-ESM catalog
# - We apply three different bias-correction techniques to pairs of CMIP6 models, treating one of the models in the pair as pseudo-observations
# - The bias-correction techniques are Moment Delta Mapping, Quantile Delta Mapping+ sort and a shift in DMT

# %%
from matplotlib import pyplot as plt
import xarray as xr
import numpy as np
import dask_jobqueue
from dask.diagnostics import progress
from tqdm.autonotebook import tqdm
import cartopy.io.shapereader as shpreader
import cartopy.feature as cfeature
import intake
import fsspec
import xarray_regrid 
#import seaborn as sns
import s3fs
import cftime
import pandas as pd
# Out:
# /glade/derecho/scratch/harshah/tmp/ipykernel_8758/417568950.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
import dask 
from dask_jobqueue import PBSCluster
from dask.distributed import Client
from dask.distributed import performance_report

# %%
# Decide whether to re-calculate everything
RECALC = True
#
pi_year  = 1865
eoc_year = 2085
#
chic_lat  = 41.8781
chic_lon  = (360-87.6298)%360
ben_lat   = 12.9716
ben_lon   = 77.5946
#
rda_scratch = '/gpfs/csfs1/collections/rda/scratch/harshah'
rda_url     =  'https://data.rda.ucar.edu/'
catalog_url = rda_url +  'd850001/catalogs/osdf/cmip6-aws/cmip6-osdf-zarr.json'
# catalog_url = 'https://cmip6-pds.s3.amazonaws.com/pangeo-cmip6.json'
rda_data    = '/gpfs/csfs1/collections/rda/data/harshah/osdf_data/'
#
tmean_path  = rda_data + 'tmean/'
tmax_path   = rda_data + 'tmax/'
tmin_path   = rda_data + 'tmin/'

# %%
# Create a PBS cluster object
cluster = PBSCluster(
    job_name = 'dask-wk25-mdm',
    cores = 1,
    memory = '8GiB',
    processes = 1,
    local_directory = rda_scratch+'/dask/spill',
    log_directory = rda_scratch + '/dask/logs/',
    resource_spec = 'select=1:ncpus=1:mem=8GB',
    queue = 'casper',
    walltime = '5:00:00',
    interface = 'ext'
)
# Out:
# /glade/u/home/harshah/venvs/osdf/lib/python3.10/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39621 instead
#   warnings.warn(

# %%
# Create the client to load the Dashboard
client = Client(cluster)

# %%
n_workers =8
cluster.scale(n_workers)
client.wait_for_workers(n_workers = n_workers)
cluster
# Out:
# PBSCluster(137d5038, 'tcp://128.117.208.115:34669', workers=8, threads=8, memory=64.00 GiB)

# %%
# calculate global means
def get_lat_name(ds):
    for lat_name in ['lat', 'latitude']:
        if lat_name in ds.coords:
            return lat_name
    raise RuntimeError("Couldn't find a latitude coordinate")

def global_mean(ds):
    lat = ds[get_lat_name(ds)]
    weight = np.cos(np.deg2rad(lat))
    weight /= weight.mean()
    other_dims = set(ds.dims) - {'quantile'}
    return (ds * weight).mean(other_dims)

def detrend_data(ds, central_year):
    # Assumes that the ds has coordinates day, year and member.
    
    #Fit a linear fuction and extract slope
    pcoeffs = ds.polyfit(dim='year',deg=1)
    slope   = pcoeffs.polyfit_coefficients.sel(degree=1)
    
    #Calculate trend
    ds_trend   = slope*(ds['year']- central_year)
    
    #Detrend by subtracting the trend from the data
    ds_detrended = ds  - ds_trend
    
    return ds_detrended

# %% [markdown]
# ## Section 2: Load Data

# %%
col = intake.open_esm_datastore(catalog_url)
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7780 dataset(s) from 522217 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>709</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>522217</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>744</td>
#     </tr>
#     <tr>
#       <th>derived_variable_id</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
var_name    = 'tas'
folder_path = tmean_path
variable    = ['tas'] #Other variables of interest: 'tasmax', 'tasmin'

# %%
# 2. Search for daily temperature 
expts = ['ssp370','historical']

query = dict(
    experiment_id=expts,
    table_id='day',
    variable_id= variable,
    member_id = 'r1i1p1f1',
    #activity_id = 'CMIP',
    
)

col_subset = col.search(require_all_on=["source_id"], **query)

col_subset.df.groupby("source_id")[["experiment_id", "variable_id", "table_id","member_id"]].nunique()
# Out:
#                    experiment_id  variable_id  table_id  member_id
# source_id
# ACCESS-CM2                     2            1         1          1
# AWI-CM-1-1-MR                  2            1         1          1
# BCC-CSM2-MR                    2            1         1          1
# BCC-ESM1                       2            1         1          1
# CESM2-WACCM                    2            1         1          1
# CMCC-CM2-SR5                   2            1         1          1
# CMCC-ESM2                      2            1         1          1
# CanESM5                        2            1         1          1
# EC-Earth3                      2            1         1          1
# EC-Earth3-AerChem              2            1         1          1
# EC-Earth3-Veg                  2            1         1          1
# EC-Earth3-Veg-LR               2            1         1          1
# FGOALS-g3                      2            1         1          1
# GFDL-ESM4                      2            1         1          1
# IITM-ESM                       2            1         1          1
# INM-CM4-8                      2            1         1          1
# INM-CM5-0                      2            1         1          1
# IPSL-CM5A2-INCA                2            1         1          1
# IPSL-CM6A-LR                   2            1         1          1
# KACE-1-0-G                     2            1         1          1
# MIROC6                         2            1         1          1
# MPI-ESM-1-2-HAM                2            1         1          1
# MPI-ESM1-2-HR                  2            1         1          1
# MPI-ESM1-2-LR                  2            1         1          1
# MRI-ESM2-0                     2            1         1          1
# NorESM2-LM                     2            1         1          1
# NorESM2-MM                     2            1         1          1

# %%
df = col_subset.df
# model_counts = df.groupby('source_id').size()
# print(model_counts)
df.head()
# Out:
#    activity_id institution_id      source_id experiment_id member_id table_id  \
# 0         CMIP   CSIRO-ARCCSS     ACCESS-CM2    historical  r1i1p1f1      day
# 1  ScenarioMIP   CSIRO-ARCCSS     ACCESS-CM2        ssp370  r1i1p1f1      day
# 2         CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1      day
# 3  ScenarioMIP            AWI  AWI-CM-1-1-MR        ssp370  r1i1p1f1      day
# 4         CMIP            BCC    BCC-CSM2-MR    historical  r1i1p1f1      day
#
#   variable_id grid_label                                             zstore  \
# 0         tas         gn  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...
# 1         tas         gn  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...
# 2         tas         gn  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...
# 3         tas         gn  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...
# 4         tas         gn  osdf:///aws-opendata/us-west-2/cmip6-pds/CMIP6...
#
#    dcpp_init_year   version
# 0             NaN  20191108
# 1             NaN  20191108
# 2             NaN  20181218
# 3             NaN  20190529
# 4             NaN  20181126

# %%
df['activity_id'].unique()
# Out:
# array(['CMIP', 'ScenarioMIP', 'AerChemMIP'], dtype=object)

# %%
# Keep only rows with CMIP (historical) or ScenarioMIP (ssp370) for consistency. 
df_filtered = col_subset.df[col_subset.df['activity_id'].isin(['CMIP', 'ScenarioMIP'])]

print("Filtered DataFrame shape:", df_filtered.shape)
# print("Filtered activity_id values:", df_filtered['activity_id'])
# Out:
# Filtered DataFrame shape: (53, 11)

# %%
df_filtered.groupby("source_id")[["experiment_id", "variable_id", "table_id","activity_id"]].nunique()
# Out:
#                    experiment_id  variable_id  table_id  activity_id
# source_id
# ACCESS-CM2                     2            1         1            2
# AWI-CM-1-1-MR                  2            1         1            2
# BCC-CSM2-MR                    2            1         1            2
# BCC-ESM1                       1            1         1            1
# CESM2-WACCM                    2            1         1            2
# CMCC-CM2-SR5                   2            1         1            2
# CMCC-ESM2                      2            1         1            2
# CanESM5                        2            1         1            2
# EC-Earth3                      2            1         1            2
# EC-Earth3-AerChem              2            1         1            2
# EC-Earth3-Veg                  2            1         1            2
# EC-Earth3-Veg-LR               2            1         1            2
# FGOALS-g3                      2            1         1            2
# GFDL-ESM4                      2            1         1            2
# IITM-ESM                       2            1         1            2
# INM-CM4-8                      2            1         1            2
# INM-CM5-0                      2            1         1            2
# IPSL-CM5A2-INCA                2            1         1            2
# IPSL-CM6A-LR                   2            1         1            2
# KACE-1-0-G                     2            1         1            2
# MIROC6                         2            1         1            2
# MPI-ESM-1-2-HAM                2            1         1            2
# MPI-ESM1-2-HR                  2            1         1            2
# MPI-ESM1-2-LR                  2            1         1            2
# MRI-ESM2-0                     2            1         1            2
# NorESM2-LM                     2            1         1            2
# NorESM2-MM                     2            1         1            2

# %%
# %%time
# dsets = col_subset.to_dataset_dict(storage_options={'anon': 'True'})
dsets = col_subset.to_dataset_dict()
print(f"\nDataset dictionary keys:\n {dsets.keys()}")
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='54' class='' max='54' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [54/54 01:15&lt;00:00]
#     </div>
# Dataset dictionary keys:
#  dict_keys(['CMIP.CCCma.CanESM5.historical.day.gn', 'CMIP.MPI-M.MPI-ESM1-2-HR.historical.day.gn', 'ScenarioMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.ssp370.day.gn', 'CMIP.NOAA-GFDL.GFDL-ESM4.historical.day.gr1', 'CMIP.NCC.NorESM2-MM.historical.day.gn', 'ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg.ssp370.day.gr', 'ScenarioMIP.CMCC.CMCC-ESM2.ssp370.day.gn', 'CMIP.BCC.BCC-ESM1.historical.day.gn', 'ScenarioMIP.IPSL.IPSL-CM5A2-INCA.ssp370.day.gr', 'ScenarioMIP.NIMS-KMA.KACE-1-0-G.ssp370.day.gr', 'CMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.historical.day.gr', 'ScenarioMIP.EC-Earth-Consortium.EC-Earth3.ssp370.day.gr', 'ScenarioMIP.NOAA-GFDL.GFDL-ESM4.ssp370.day.gr1', 'ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp370.day.gn', 'ScenarioMIP.EC-Earth-Consortium.EC-Earth3-AerChem.ssp370.day.gr', 'ScenarioMIP.AWI.AWI-CM-1-1-MR.ssp370.day.gn', 'CMIP.BCC.BCC-CSM2-MR.historical.day.gn', 'ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp370.day.gr', 'CMIP.IPSL.IPSL-CM5A2-INCA.historical.day.gr', 'CMIP.CAS.FGOALS-g3.historical.day.gn', 'CMIP.NCAR.CESM2-WACCM.historical.day.gn', 'CMIP.MPI-M.MPI-ESM1-2-LR.historical.day.gn', 'ScenarioMIP.MRI.MRI-ESM2-0.ssp370.day.gn', 'CMIP.CCCR-IITM.IITM-ESM.historical.day.gn', 'ScenarioMIP.NCC.NorESM2-LM.ssp370.day.gn', 'CMIP.EC-Earth-Consortium.EC-Earth3-Veg.historical.day.gr', 'ScenarioMIP.BCC.BCC-CSM2-MR.ssp370.day.gn', 'ScenarioMIP.EC-Earth-Consortium.EC-Earth3-Veg-LR.ssp370.day.gr', 'CMIP.INM.INM-CM5-0.historical.day.gr1', 'ScenarioMIP.INM.INM-CM5-0.ssp370.day.gr1', 'ScenarioMIP.NCC.NorESM2-MM.ssp370.day.gn', 'ScenarioMIP.CCCR-IITM.IITM-ESM.ssp370.day.gn', 'ScenarioMIP.MPI-M.MPI-ESM1-2-LR.ssp370.day.gn', 'ScenarioMIP.CCCma.CanESM5.ssp370.day.gn', 'ScenarioMIP.MIROC.MIROC6.ssp370.day.gn', 'CMIP.AWI.AWI-CM-1-1-MR.historical.day.gn', 'CMIP.HAMMOZ-Consortium.MPI-ESM-1-2-HAM.historical.day.gn', 'AerChemMIP.BCC.BCC-ESM1.ssp370.day.gn', 'CMIP.NIMS-KMA.KACE-1-0-G.historical.day.gr', 'CMIP.CMCC.CMCC-ESM2.historical.day.gn', 'CMIP.EC-Earth-Consortium.EC-Earth3.historical.day.gr', 'ScenarioMIP.INM.INM-CM4-8.ssp370.day.gr1', 'CMIP.NCC.NorESM2-LM.historical.day.gn', 'CMIP.CMCC.CMCC-CM2-SR5.historical.day.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.day.gr', 'CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.day.gn', 'CMIP.INM.INM-CM4-8.historical.day.gr1', 'CMIP.MRI.MRI-ESM2-0.historical.day.gn', 'ScenarioMIP.CMCC.CMCC-CM2-SR5.ssp370.day.gn', 'ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp370.day.gn', 'ScenarioMIP.NCAR.CESM2-WACCM.ssp370.day.gn', 'ScenarioMIP.CAS.FGOALS-g3.ssp370.day.gn', 'CMIP.EC-Earth-Consortium.EC-Earth3-AerChem.historical.day.gr', 'CMIP.MIROC.MIROC6.historical.day.gn'])
# CPU times: user 10.1 s, sys: 569 ms, total: 10.7 s
# Wall time: 1min 15s

# %%
def drop_all_bounds(ds):
    drop_vars = [vname for vname in ds.coords
                 if (('_bounds') in vname ) or ('_bnds') in vname]
    return ds.drop_vars(drop_vars)

def open_dset(df):
    assert len(df) == 1
    
    # Force anonymous access for public datasets
    storage_options = {'anon': True}
    # ds = xr.open_zarr(fsspec.get_mapper(df.zstore.values[0], **storage_options),consolidated=True) #For s3fs protocol
    ds = xr.open_zarr(fsspec.get_mapper(df.zstore.values[0]), consolidated=True) #Use for PelicanFS
    return drop_all_bounds(ds)

def open_delayed(df):
    return dask.delayed(open_dset)(df)

from collections import defaultdict
dsets = defaultdict(dict)

for group, df in col_subset.df.groupby(by=['source_id', 'experiment_id']):
    dsets[group[0]][group[1]] = open_delayed(df)

# %%
# %%time
# Trigger computation
dsets_ = dask.compute(dict(dsets))[0]
# Out:
# CPU times: user 5.53 s, sys: 233 ms, total: 5.76 s
# Wall time: 18.8 s

# %%
#Define coarse grid to regrid on 1 *1 degree card
ds_out = xr.Dataset({'lat': (['lat'], np.arange(-90, 91, 1.5)),
                    'lon': (['lon'], np.arange(0, 361, 1.5))})
ds_out
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:  (lat: 121, lon: 241)
# Coordinates:
#   * lat      (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 85.5 87.0 88.5 90.0
#   * lon      (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     *empty*

# %%
def drop_feb29(ds):
    # Check if the dataset's calendar is not '360_day'
    calendar = ds.time.encoding.get('calendar', None)
    print(ds.attrs['source_id'],calendar)
    if calendar != '360_day':
        ds = ds.convert_calendar('365_day')
    return ds


def to_daily(ds):
    # Check and deal with different datetime types
    if isinstance(ds['time'].values[0], np.datetime64):
        pass
    elif isinstance(ds['time'].values[0], cftime.datetime):
        pass
    else:
        # convert time coordinate to datetime64 objects
        ds['time'] = ds['time'].astype('datetime64[ns]')
    year      = ds.time.dt.year
    dayofyear = ds.time.dt.dayofyear

    # assign new coords
    ds = ds.assign_coords(year=("time", year.data), dayofyear=("time", dayofyear.data))

    # reshape the array to (..., "day", "year")
    return ds.set_index(time=("year", "dayofyear")).unstack("time")  


def extract_data(ds):
    """
    Extract data from the dataset 'ds' for specific time and spatial range.

    Parameters:
    - ds (xarray.Dataset): Input dataset

    Returns:
    - xarray.Dataset: Dataset subsetted for required years and the specified space and time range.
    """    

    subset1 = ds.sel(year=slice(1850, 1879))
    subset2 = ds.sel(year=slice(2071, 2100))
    
    subset = xr.concat([subset1, subset2], dim='year')  

    return subset

def is_leap(year):
    """Check if a year is a leap year."""
    return (year % 4 == 0) and ((year % 100 != 0) or (year % 400 == 0))

# %%
quants = np.linspace(0,1.0,30)

def compute_quantiles(ds, quantiles=quants):
    return ds.chunk(dict(year=-1)).quantile(quantiles, dim='year',skipna=False)

def regrid(ds, ds_out):
    experiment_id = ds.attrs['experiment_id']
    source_id     = ds.attrs['source_id']
    ds_new   = ds.regrid.nearest(ds_out)
    
#     #Assign back attributes as regirdder would have deleted attributes 
    ds_new.attrs['experiment_id'] = experiment_id
    ds_new.attrs['source_id'] = source_id
    
    #print(ds_new.attrs['experiment_id'],ds_new.attrs['source_id'])
    #print(ds_new)
    return ds_new

def process_data(ds, quantiles=quants):
    ds = ds.pipe(drop_feb29).pipe(to_daily).pipe(extract_data)
    
    if len(ds['year']) == 0:
        print("The dataset is empty. Skipping...")
        return None
    
    if len(ds['dayofyear'])<365:
        print('The dataset has less than 365 days. Skipping ..')
        return None
    
    # # Remove 'time' coordinate
    # ds = ds.set_index(time=("year", "dayofyear")).unstack("time")  
    return (ds.pipe(regrid, ds_out=ds_out))

# %% [markdown]
# ## Section 3: Computations.
# - Evalulate these

# %%
# %%time
if RECALC:
    with progress.ProgressBar():
    
        expt_da = xr.DataArray(expts, dims='experiment_id', name='experiment_id',
                               coords={'experiment_id': expts})
    
        # Initialize an Empty Dictionary for Aligned Datasets:
        dsets_aligned = {}
    
        # Iterate Over dsets_ Dictionary:
    
        for k, v in tqdm(dsets_.items()):
            # Initialize a dictionary for this source_id
            dsets_aligned[k] = {}
            
            skip_source_id = False
    
            for expt in expts:
                ds = v[expt].pipe(process_data)
    
                # Check if the dataset is empty and skip this source_id if so
                if ds is None:
                    print(f"Skipping {expt} for {k} because the dataset is empty")
                    skip_source_id = True
                    break
                
                # Store the dataset in the dictionary
                # dsets_aligned[k][expt] = ds
                # Compute the dataset and store it in the dictionary
                dsets_aligned[k][expt] = ds.compute()
                print(dsets_aligned[k][expt])
    
            if skip_source_id:
                del dsets_aligned[k]
                continue
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# ACCESS-CM2 proleptic_gregorian
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 258.4 258.4 ... 266.4
# Attributes:
#     experiment_id:  ssp370
#     source_id:      ACCESS-CM2
# ACCESS-CM2 proleptic_gregorian
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 257.0 257.0 ... 230.0
# Attributes:
#     experiment_id:  historical
#     source_id:      ACCESS-CM2
# AWI-CM-1-1-MR proleptic_gregorian
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 245.9 245.9 ... 265.9
# Attributes:
#     experiment_id:  ssp370
#     source_id:      AWI-CM-1-1-MR
# AWI-CM-1-1-MR proleptic_gregorian
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 246.9 246.9 ... 245.1
# Attributes:
#     experiment_id:  historical
#     source_id:      AWI-CM-1-1-MR
# BCC-CSM2-MR noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 250.7 250.7 ... 256.7
# Attributes:
#     experiment_id:  ssp370
#     source_id:      BCC-CSM2-MR
# BCC-CSM2-MR noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 249.7 249.7 ... 240.8
# Attributes:
#     experiment_id:  historical
#     source_id:      BCC-CSM2-MR
# BCC-ESM1 noleap
# The dataset is empty. Skipping...
# Skipping ssp370 for BCC-ESM1 because the dataset is empty
# CESM2-WACCM noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (lat: 121, lon: 241, year: 30, dayofyear: 365)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (lat, lon, year, dayofyear) float32 1GB 254.3 253.9 ... 266.8
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP
#     branch_method:          standard
#     branch_time_in_child:   735110.0
#     branch_time_in_parent:  735110.0
#     case_id:                969
#     ...                     ...
#     tracking_id:            hdl:21.14100/510f4e10-213c-4da9-a0db-df8eb054f145...
#     variable_id:            tas
#     variant_info:           CMIP6 CESM2 future scenario SSP3-7.0, years 2015-...
#     variant_label:          r1i1p1f1
#     netcdf_tracking_ids:    hdl:21.14100/510f4e10-213c-4da9-a0db-df8eb054f145...
#     version_id:             v20190815
# CESM2-WACCM noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (lat: 121, lon: 241, year: 30, dayofyear: 365)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (lat, lon, year, dayofyear) float32 1GB 242.7 243.2 ... 235.9
# Attributes: (12/48)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   674885.0
#     branch_time_in_parent:  20075.0
#     case_id:                4
#     ...                     ...
#     variable_id:            tas
#     variant_info:           CMIP6 CESM2 hindcast (1850-2014) with high-top at...
#     variant_label:          r1i1p1f1
#     status:                 2019-11-04;created;by nhn2@columbia.edu
#     netcdf_tracking_ids:    hdl:21.14100/a97ad3ae-0194-47a6-92eb-3c19fc17a0b3...
#     version_id:             v20190227
# CMCC-CM2-SR5 noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (lat: 121, lon: 241, year: 30, dayofyear: 365)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (lat, lon, year, dayofyear) float32 1GB 260.4 259.5 ... 275.7
# Attributes: (12/51)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP AerChemMIP
#     branch_method:          standard
#     branch_time_in_child:   60225.0
#     branch_time_in_parent:  60225.0
#     cmor_version:           3.5.0
#     ...                     ...
#     title:                  CMCC-CM2-SR5 output prepared for CMIP6
#     tracking_id:            hdl:21.14100/a346797b-0e02-4358-9175-6b75b6145a7b...
#     variable_id:            tas
#     variant_label:          r1i1p1f1
#     netcdf_tracking_ids:    hdl:21.14100/a346797b-0e02-4358-9175-6b75b6145a7b...
#     version_id:             v20200622
# CMCC-CM2-SR5 noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (lat: 121, lon: 241, year: 30, dayofyear: 365)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (lat, lon, year, dayofyear) float32 1GB 254.5 253.3 ... 261.1
# Attributes: (12/51)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     cmor_version:           3.5.0
#     ...                     ...
#     title:                  CMCC-CM2-SR5 output prepared for CMIP6
#     tracking_id:            hdl:21.14100/41bcc313-4397-4f5d-aae5-7d69407a79c6...
#     variable_id:            tas
#     variant_label:          r1i1p1f1
#     netcdf_tracking_ids:    hdl:21.14100/41bcc313-4397-4f5d-aae5-7d69407a79c6...
#     version_id:             v20200616
# CMCC-ESM2 noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (lat: 121, lon: 241, year: 30, dayofyear: 365)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (lat, lon, year, dayofyear) float32 1GB 263.2 263.5 ... 273.8
# Attributes: (12/51)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            ScenarioMIP AerChemMIP
#     branch_method:          standard
#     branch_time_in_child:   60225.0
#     branch_time_in_parent:  60225.0
#     cmor_version:           3.6.0
#     ...                     ...
#     table_info:             Creation Date:(05 February 2020) MD5:6a248fd76c55...
#     title:                  CMCC-ESM2 output prepared for CMIP6
#     tracking_id:            hdl:21.14100/730bd4fc-e20d-4294-a8e9-ece7dbc1c9c5
#     variable_id:            tas
#     variant_label:          r1i1p1f1
#     version_id:             v20210202
# CMCC-ESM2 noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (lat: 121, lon: 241, year: 30, dayofyear: 365)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (lat, lon, year, dayofyear) float32 1GB 254.6 253.3 ... 241.3
# Attributes: (12/51)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
#     cmor_version:           3.6.0
#     ...                     ...
#     table_info:             Creation Date:(05 February 2020) MD5:6a248fd76c55...
#     title:                  CMCC-ESM2 output prepared for CMIP6
#     tracking_id:            hdl:21.14100/db04e514-a2a5-4941-b9fa-bdd7b4781f69
#     variable_id:            tas
#     variant_label:          r1i1p1f1
#     version_id:             v20210114
# CanESM5 noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 2071 2072 2073 2074 ... 2097 2098 2099 2100
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 256.9 256.9 ... 273.9
# Attributes:
#     experiment_id:  ssp370
#     source_id:      CanESM5
# CanESM5 noleap
# <xarray.Dataset> Size: 1GB
# Dimensions:    (year: 30, dayofyear: 365, lat: 121, lon: 241)
# Coordinates:
#   * year       (year) int64 240B 1850 1851 1852 1853 ... 1876 1877 1878 1879
#   * dayofyear  (dayofyear) int64 3kB 1 2 3 4 5 6 7 ... 360 361 362 363 364 365
#     height     float64 8B 2.0
#   * lat        (lat) float64 968B -90.0 -88.5 -87.0 -85.5 ... 87.0 88.5 90.0
#   * lon        (lon) float64 2kB 0.0 1.5 3.0 4.5 6.0 ... 355.5 357.0 358.5 360.0
# Data variables:
#     tas        (year, dayofyear, lat, lon) float32 1GB 251.2 251.2 ... 236.8
# Attributes:
#     experiment_id:  historical
#     source_id:      CanESM5
# EC-Earth3 proleptic_gregorian
# ---------------------------------------------------------------------------
# ContentLengthError                        Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/client_proto.py:94, in connection_lost()
#      93 try:
# ---> 94     uncompleted = self._parser.feed_eof()
#      95 except Exception as underlying_exc:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/_http_parser.pyx:510, in aiohttp._http_parser.HttpParser.feed_eof()
#     509 elif self._cparser.flags & cparser.F_CONTENT_LENGTH:
# --> 510     raise ContentLengthError(
#     511         "Not enough data for satisfy content length header.")
#
# ContentLengthError: 400, message:
#   Not enough data for satisfy content length header.
#
# The above exception was the direct cause of the following exception:
#
# ClientPayloadError                        Traceback (most recent call last)
# File <timed exec>:30
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataset.py:1072, in Dataset.compute(self, **kwargs)
#    1048 """Manually trigger loading and/or computation of this dataset's data
#    1049 from disk or a remote source into memory and return a new dataset.
#    1050 Unlike load, the original dataset is left unaltered.
#    (...)
#    1069 dask.compute
#    1070 """
#    1071 new = self.copy(deep=False)
# -> 1072 return new.load(**kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/dataset.py:899, in Dataset.load(self, **kwargs)
#     896 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     898 # evaluate all the chunked arrays simultaneously
# --> 899 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     900     *lazy_data.values(), **kwargs
#     901 )
#     903 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     904     self.variables[k].data = data
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/dask/base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:580, in __array__()
#     578     return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     579 else:
# --> 580     return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:583, in get_duck_array()
#     582 def get_duck_array(self):
# --> 583     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:794, in get_duck_array()
#     793 def get_duck_array(self):
# --> 794     return self.array.get_duck_array()
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:664, in get_duck_array()
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
# --> 664     array = array.get_duck_array()
#     665 return _wrap_numpy_scalars(array)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/coding/variables.py:81, in get_duck_array()
#      80 def get_duck_array(self):
# ---> 81     return self.func(self.array.get_duck_array())
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:657, in get_duck_array()
#     653     array = apply_indexer(self.array, self.key)
#     654 else:
#     655     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     656     # it may wrap a BackendArray so use its __getitem__
# --> 657     array = self.array[self.key]
#     659 # self.array[self.key] is now a numpy array when
#     660 # self.array is a BackendArray subclass
#     661 # and self.key is BasicIndexer((slice(None, None, None),))
#     662 # so we need the explicit check for ExplicitlyIndexed
#     663 if isinstance(array, ExplicitlyIndexed):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:226, in __getitem__()
#     224 elif isinstance(key, indexing.OuterIndexer):
#     225     method = self._oindex
# --> 226 return indexing.explicit_indexing_adapter(
#     227     key, array.shape, indexing.IndexingSupport.VECTORIZED, method
#     228 )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/core/indexing.py:1018, in explicit_indexing_adapter()
#     996 """Support explicit indexing by delegating to a raw indexing method.
#     997
#     998 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)
#    1015 Indexing result, in the form of a duck numpy-array.
#    1016 """
#    1017 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1018 result = raw_indexing_method(raw_key.tuple)
#    1019 if numpy_indices.tuple:
#    1020     # index the loaded np.ndarray
#    1021     indexable = NumpyIndexingAdapter(result)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:216, in _getitem()
#     215 def _getitem(self, key):
# --> 216     return self._array[key]
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:795, in __getitem__()
#     793     result = self.vindex[selection]
#     794 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 795     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     796 else:
#     797     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1077, in get_orthogonal_selection()
#    1074 # setup indexer
#    1075 indexer = OrthogonalIndexer(selection, self)
# -> 1077 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:1340, in _get_selection()
#    1337 if math.prod(out_shape) > 0:
#    1338     # allow storage to get multiple items at once
#    1339     lchunk_coords, lchunk_selection, lout_selection = zip(*indexer)
# -> 1340     self._chunk_getitems(
#    1341         lchunk_coords,
#    1342         lchunk_selection,
#    1343         out,
#    1344         lout_selection,
#    1345         drop_axes=indexer.drop_axes,
#    1346         fields=fields,
#    1347     )
#    1348 if out.shape:
#    1349     return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/core.py:2181, in _chunk_getitems()
#    2179     if not isinstance(self._meta_array, np.ndarray):
#    2180         contexts = ConstantMap(ckeys, constant=Context(meta_array=self._meta_array))
# -> 2181     cdatas = self.chunk_store.getitems(ckeys, contexts=contexts)
#    2183 for ckey, chunk_select, out_select in zip(ckeys, lchunk_selection, lout_selection):
#    2184     if ckey in cdatas:
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1435, in getitems()
#    1432     continue
#    1433 elif isinstance(v, Exception):
#    1434     # Raise any other exception
# -> 1435     raise v
#    1436 else:
#    1437     # The function calling this method may not recognize the transformed
#    1438     # keys, so we send the values returned by self.map.getitems back into
#    1439     # the original key space.
#    1440     results[keys_transformed[k]] = v
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/asyn.py:245, in _run_coro()
#     243 async def _run_coro(coro, i):
#     244     try:
# --> 245         return await asyncio.wait_for(coro, timeout=timeout), i
#     246     except Exception as e:
#     247         if not return_exceptions:
#
# File /glade/u/apps/jupyterhub/jh-23.11/lib/python3.10/asyncio/tasks.py:408, in wait_for()
#     405 loop = events.get_running_loop()
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#     411     fut = ensure_future(fut, loop=loop)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/fsspec/implementations/http.py:235, in _cat_file()
#     233 session = await self.set_session()
#     234 async with session.get(self.encode_url(url), **kw) as r:
# --> 235     out = await r.read()
#     236     self._raise_not_found_for_status(r, url)
#     237 return out
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/client_reqrep.py:1111, in read()
#    1109 if self._body is None:
#    1110     try:
# -> 1111         self._body = await self.content.read()
#    1112         for trace in self._traces:
#    1113             await trace.send_response_chunk_received(
#    1114                 self.method, self.url, self._body
#    1115             )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:383, in read()
#     381 blocks = []
#     382 while True:
# --> 383     block = await self.readany()
#     384     if not block:
#     385         break
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:405, in readany()
#     401 # TODO: should be `if` instead of `while`
#     402 # because waiter maybe triggered on chunk end,
#     403 # without feeding any data
#     404 while not self._buffer and not self._eof:
# --> 405     await self._wait("readany")
#     407 return self._read_nowait(-1)
#
# File ~/venvs/osdf/lib/python3.10/site-packages/aiohttp/streams.py:312, in _wait()
#     310 try:
#     311     with self._timer:
# --> 312         await waiter
#     313 finally:
#     314     self._waiter = None
#
# ClientPayloadError: Response payload is not completed: <ContentLengthError: 400, message='Not enough data for satisfy content length header.'>

# %%
# dsets_aligned.keys()

# %%
# %%time
if RECALC:
    source_ids = list(dsets_aligned.keys())
    source_da = xr.DataArray(source_ids, dims='source_id', name='source_id',
                         coords={'source_id': source_ids})
    final_ds_pi = xr.concat([ds['historical'].reset_coords(drop=True)
                                     for ds in dsets_aligned.values()],
                                    dim=source_da)
    
    final_ds_eoc = xr.concat([ds['ssp370'].reset_coords(drop=True)
                                 for ds in dsets_aligned.values()],
                                dim=source_da)
    final_ds_eoc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File <timed exec>:5
#
# File <timed exec>:5, in <listcomp>(.0)
#
# KeyError: 'historical'

# %%
# %%time
final_ds_pi.to_zarr(folder_path  +'cmip6_pi_daily.zarr',mode='w')
final_ds_eoc.to_zarr(folder_path +'cmip6_eoc_daily.zarr',mode='w')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# NameError: name 'final_ds_pi' is not defined

# %%
final_ds_pi  = xr.open_zarr(folder_path+'cmip6_pi_daily.zarr')
final_ds_eoc = xr.open_zarr(folder_path+'cmip6_eoc_daily.zarr')
final_ds_pi  = final_ds_pi[var_name]
final_ds_eoc = final_ds_eoc[var_name]
final_ds_eoc
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1704, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1703 try:
# -> 1704     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#    1705 except (ValueError, KeyError):
#    1706     # ValueError in zarr-python 3.x, KeyError in 2.x.
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/convenience.py:1360, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1359 # setup metadata store
# -> 1360 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1362 # pass through
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:3046, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3045 # retrieve consolidated metadata
# -> 3046 meta = json_loads(self.store[metadata_key])
#    3048 # check format of consolidated metadata
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/storage.py:1120, in DirectoryStore.__getitem__(self, key)
#    1119 else:
# -> 1120     raise KeyError(key)
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1708, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1707 try:
# -> 1708     zarr_group = zarr.open_group(store, **open_kwargs)
#    1709     emit_user_level_warning(
#    1710         "Failed to open Zarr store with consolidated metadata, "
#    1711         "but successfully read with non-consolidated metadata. "
#    (...)
#    1721         RuntimeWarning,
#    1722     )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/zarr/hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 final_ds_pi  = xr.open_zarr(folder_path+'cmip6_pi_daily.zarr')
#       2 final_ds_eoc = xr.open_zarr(folder_path+'cmip6_eoc_daily.zarr')
#       3 final_ds_pi  = final_ds_pi[var_name]
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1436, in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, chunk_store, storage_options, decode_timedelta, use_cftime, zarr_version, zarr_format, use_zarr_fill_value_as_mask, chunked_array_type, from_array_kwargs, **kwargs)
#    1422     raise TypeError(
#    1423         "open_zarr() got unexpected keyword arguments " + ",".join(kwargs.keys())
#    1424     )
#    1426 backend_kwargs = {
#    1427     "synchronizer": synchronizer,
#    1428     "consolidated": consolidated,
#    (...)
#    1433     "zarr_format": zarr_format,
#    1434 }
# -> 1436 ds = open_dataset(
#    1437     filename_or_obj=store,
#    1438     group=group,
#    1439     decode_cf=decode_cf,
#    1440     mask_and_scale=mask_and_scale,
#    1441     decode_times=decode_times,
#    1442     concat_characters=concat_characters,
#    1443     decode_coords=decode_coords,
#    1444     engine="zarr",
#    1445     chunks=chunks,
#    1446     drop_variables=drop_variables,
#    1447     chunked_array_type=chunked_array_type,
#    1448     from_array_kwargs=from_array_kwargs,
#    1449     backend_kwargs=backend_kwargs,
#    1450     decode_timedelta=decode_timedelta,
#    1451     use_cftime=use_cftime,
#    1452     zarr_version=zarr_version,
#    1453     use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#    1454 )
#    1455 return ds
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/api.py:670, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 670 backend_ds = backend.open_dataset(
#     671     filename_or_obj,
#     672     drop_variables=drop_variables,
#     673     **decoders,
#     674     **kwargs,
#     675 )
#     676 ds = _dataset_from_backend_dataset(
#     677     backend_ds,
#     678     filename_or_obj,
#    (...)
#     688     **kwargs,
#     689 )
#     690 return ds
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1508, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, zarr_version, zarr_format, store, engine, use_zarr_fill_value_as_mask)
#    1506 filename_or_obj = _normalize_path(filename_or_obj)
#    1507 if not store:
# -> 1508     store = ZarrStore.open_group(
#    1509         filename_or_obj,
#    1510         group=group,
#    1511         mode=mode,
#    1512         synchronizer=synchronizer,
#    1513         consolidated=consolidated,
#    1514         consolidate_on_close=False,
#    1515         chunk_store=chunk_store,
#    1516         storage_options=storage_options,
#    1517         zarr_version=zarr_version,
#    1518         use_zarr_fill_value_as_mask=None,
#    1519         zarr_format=zarr_format,
#    1520     )
#    1522 store_entrypoint = StoreBackendEntrypoint()
#    1523 with close_on_error(store):
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:693, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, zarr_version, zarr_format, use_zarr_fill_value_as_mask, write_empty)
#     669 @classmethod
#     670 def open_group(
#     671     cls,
#    (...)
#     686     write_empty: bool | None = None,
#     687 ):
#     688     (
#     689         zarr_group,
#     690         consolidate_on_close,
#     691         close_store_on_close,
#     692         use_zarr_fill_value_as_mask,
# --> 693     ) = _get_open_params(
#     694         store=store,
#     695         mode=mode,
#     696         synchronizer=synchronizer,
#     697         group=group,
#     698         consolidated=consolidated,
#     699         consolidate_on_close=consolidate_on_close,
#     700         chunk_store=chunk_store,
#     701         storage_options=storage_options,
#     702         zarr_version=zarr_version,
#     703         use_zarr_fill_value_as_mask=use_zarr_fill_value_as_mask,
#     704         zarr_format=zarr_format,
#     705     )
#     707     return cls(
#     708         zarr_group,
#     709         mode,
#    (...)
#     716         use_zarr_fill_value_as_mask,
#     717     )
#
# File ~/venvs/osdf/lib/python3.10/site-packages/xarray/backends/zarr.py:1724, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, zarr_version, use_zarr_fill_value_as_mask, zarr_format)
#    1709             emit_user_level_warning(
#    1710                 "Failed to open Zarr store with consolidated metadata, "
#    1711                 "but successfully read with non-consolidated metadata. "
#    (...)
#    1721                 RuntimeWarning,
#    1722             )
#    1723         except missing_exc as err:
# -> 1724             raise FileNotFoundError(
#    1725                 f"No such file or directory: '{store}'"
#    1726             ) from err
#    1727 elif consolidated:
#    1728     # TODO: an option to pass the metadata_key keyword
#    1729     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#
# FileNotFoundError: No such file or directory: '/gpfs/csfs1/collections/rda/data/harshah/osdf_data/tmean/cmip6_pi_daily.zarr'

# %% [markdown]
# ### Detrend data and save

# %%
# %%time
ds_pi_det  = detrend_data(final_ds_pi,pi_year)
ds_eoc_det = detrend_data(final_ds_eoc,eoc_year)
ds_eoc_det = ds_eoc_det.chunk({'year':30,'source_id':1})
ds_pi_det = ds_pi_det.chunk({'year':30,'source_id':1})
ds_eoc_det

# %%
# %%time
# ds_pi_det.rename(var_name).to_dataset().to_zarr(folder_path  +'cmip6_pi_ann_detrended.zarr',mode='w')

# %%
# %%time
# ds_eoc_det.rename(var_name).to_dataset().to_zarr(folder_path +'cmip6_eoc_ann_detrended.zarr',mode='w')

# %% [markdown]
# ### Check if detrending worked

# %%
ds_pi_det  = xr.open_zarr(folder_path  +'cmip6_pi_ann_detrended.zarr')
ds_eoc_det = xr.open_zarr(folder_path +'cmip6_eoc_ann_detrended.zarr')
#
ds_pi_det  = ds_pi_det[var_name]
ds_eoc_det = ds_eoc_det[var_name]

# %%
# %%time
ds_pi_det.sel(lat=chic_lat,lon=chic_lon,method='nearest').sel(dayofyear=2).mean('source_id').plot()
final_ds_pi.sel(lat=chic_lat,lon=chic_lon,method='nearest').sel(dayofyear=2).mean('source_id').plot()

# %%
# %%time
ds_eoc_det.sel(lat=chic_lat,lon=chic_lon,method='nearest').sel(dayofyear=2).mean('source_id').plot()
final_ds_eoc.sel(lat=chic_lat,lon=chic_lon,method='nearest').sel(dayofyear=2).mean('source_id').plot()
